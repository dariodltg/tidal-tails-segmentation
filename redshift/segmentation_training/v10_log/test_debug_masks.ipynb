# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('../masks_train_VIS/mask_1000_0.25.png')

# %%
imagen_array = np.array(img)

# Mostrar la imagen
plt.figure(figsize=(20,20))
plt.imshow(imagen_array,interpolation='none',origin="lower")
plt.show()
