# %%
import copy
import cv2
import glob
import math
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import os
import pandas as pd
import seaborn as sns
from astropy.io import fits
import torch
from torch.utils.data import Dataset
from torchmetrics import Dice
from torchmetrics import Dice, JaccardIndex
import segmentation_models_pytorch as smp
# Out:
# /home2/dario/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
hiperparametros = {'nombre_notebook': 'Evaluation_NISP_J_1000imgs_v13_log_no_aug.ipynb',
                    'nombre_experimento' : 'Evaluation_NISP_J_1000imgs_v13_log_no_aug_pad',
                    'nombre_mejor_modelo_entrenado' : 'NISP_J_1000imgs_v13_log_no_aug_pad',
                    'device' : torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
                    'ruta_galaxias' : 'galaxies_test_NISP_J/galaxy_and_stream_convolved*.fits',
                    'ruta_mascaras' : '../masks_train_NISP_J/mask_',
                    'ancho_imagen_original' : 200,
                    'alto_imagen_original' : 200,
                    'ancho_imagen_deseado' : 224,
                    'alto_imagen_deseado' : 224}

# %%
def pad_to_size(image, target_h, target_w, pad_value=0):
    """Hace padding para alcanzar el tamaño deseado sin deformar"""
    h, w = image.shape[:2]
    pad_h = target_h - h
    pad_w = target_w - w
    
    # Padding simétrico
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    
    if len(image.shape) == 2:  # Para máscaras
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right)), 
                     mode='constant', constant_values=pad_value)
    else:  # Para imágenes RGB
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right), (0, 0)), 
                     mode='constant', constant_values=pad_value)

# %%
def get_galaxy_number(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[4]

def get_galaxy_magnitude(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[5]

def normalize_01(inp: np.ndarray):
    """Squash image input to the value range [0, 1] (no clipping)"""
    inp_out = (inp - np.min(inp)) / np.ptp(inp)
    return inp_out

def imagen_logaritmica(img: np.ndarray)->np.ndarray:
    """
    Escalamos de forma logarítmica la imagen para aumentar el contraste
    """
    img_log = np.log(img, where=(img>0))
    valor_minimo = np.min(img_log)
    np.putmask(img_log, img!=0, img_log+abs(valor_minimo))
    return img_log

# %%
def get_mag_stream_percentage(galaxy_number):
    
    path_catalogs_folder = "../../dataset_generation/catalogs_for_checking" 
    path_catalog = os.path.join(path_catalogs_folder, "stream_characteristics_"+str(galaxy_number)+".txt")
    df = pd.read_csv(path_catalog, delimiter=r"\s+", engine="python")
    mag_bulge = df.iloc[1, 3]
    mag_disk = df.iloc[1, 8]
    mag_stream = df.iloc[1, 13]
    zeropoint= 30.132  # For VIS, (For NISP is 30)
    flux_bulge = 10**((mag_bulge-zeropoint)/(-2.5)) 
    flux_disk = 10**((mag_disk-zeropoint)/(-2.5))
    flux_galaxy = flux_bulge + flux_disk
    flux_stream = 10**((mag_stream-zeropoint)/(-2.5)) 
    mag_stream_percentage = flux_stream/flux_galaxy
    mag_stream_percentage_rounded_up = math.ceil(mag_stream_percentage*100)
    if mag_stream_percentage_rounded_up == 6:
        mag_stream_percentage_rounded_up = 5
    print("MAG_STREAM_PERCENTAGE: " + str(mag_stream_percentage) + "->" + str(mag_stream_percentage_rounded_up)+ "%")
    return mag_stream_percentage_rounded_up

# %%
class MyDataset(Dataset):
    """
    Dataset básico sin ningún tipo de augmentation
    """
    def __init__(self, galaxias_con_colas_de_marea, transform=None):
        """
        Constructor del dataset
        @param galaxias_con_colas_de_marea: Lista de rutas a los ficheros que contienen los datos de las galaxias
        """
        self.galaxias_con_colas_de_marea = galaxias_con_colas_de_marea
        self.transform=transform

    def __getitem__(self, index):
        #Abrimos la imagen de la galaxia con cola de marea
        ruta = self.galaxias_con_colas_de_marea[index]
        magnitud_real = get_galaxy_magnitude(ruta)
        
        galaxy_fits = fits.open(self.galaxias_con_colas_de_marea[index])
        x = galaxy_fits[0].data.astype(np.float32)
        #Abrimos la mascara correspondiente a la imagen
        numero_galaxia = get_galaxy_number(self.galaxias_con_colas_de_marea[index])
        magnitud_galaxia = get_galaxy_magnitude(self.galaxias_con_colas_de_marea[index])
        mag_stream_percentage = get_mag_stream_percentage(numero_galaxia)

        y = np.array(cv2.imread(hiperparametros['ruta_mascaras']+str(numero_galaxia)+"_"+str(magnitud_galaxia)+".png",0)).astype(np.float32)
        #x = normalize_01(x)
        x_tensor_visualizar = copy.deepcopy(x)
        x = imagen_logaritmica(x)

        x = normalize_01(x)

        x = pad_to_size(x, hiperparametros['alto_imagen_deseado'], hiperparametros['ancho_imagen_deseado'])
        y = pad_to_size(y, hiperparametros['alto_imagen_deseado'], hiperparametros['ancho_imagen_deseado'])
        if(self.transform is not None):
            augmented = self.transform(image=x, mask=y)
            x_tensor= augmented["image"]
            y_tensor= augmented["mask"].long()
        else:
            x_tensor = torch.from_numpy(x).float()
            x_tensor=torch.unsqueeze(x_tensor, dim=0)
            y_tensor = torch.from_numpy(y).long()
        
        #Hacemos reshape de los tensores
        y_tensor=torch.unsqueeze(y_tensor, dim=0)
        return x_tensor, y_tensor, ruta, magnitud_real, x_tensor_visualizar, mag_stream_percentage
    
    def __len__(self):
        """
        Devuelve la longitud del dataset
        """
        return len(self.galaxias_con_colas_de_marea)

# %%
dice = Dice(num_classes=2, average='macro', ignore_index=0)
iou = JaccardIndex(task='multiclass', num_classes=2, average='none', ignore_index=0)
imagenes_test = glob.glob(hiperparametros['ruta_galaxias'])
imagenes_test.sort()
#Cargamos el dataset de test
test_dataset= MyDataset(imagenes_test)
print("Number of valid images: " + str(len(imagenes_test)))
device = hiperparametros['device']
#dice.to(device)
# Out:
# Number of valid images: 1750

# %%
unet = smp.Unet(
    encoder_name="resnet18",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
#Cargamos el modelo previamente entrenado
ruta_modelo = hiperparametros['nombre_mejor_modelo_entrenado']
mejor_modelo = unet
mejor_modelo.load_state_dict(torch.load(ruta_modelo))
mejor_modelo.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
len(test_dataset)
# Out:
# 1750

# %%
resultados_dice = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
resultados_iou = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}

dice_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}

iou_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}


# Without photos
ancho = hiperparametros['ancho_imagen_deseado']
alto =hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test=0
dice_medio_test=0
iou_medio_test = 0
zp = 30.137
pix_scale = 0.1
for i in range(int(len(test_dataset))):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    #Si la máscara es vacía no intentamos segmentarla, para que no cuente en el dice
    if(np.count_nonzero(item_label)!=0):

        #Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))[1]
        magnitud = item_dataset[3]
        mag_stream_percentage = item_dataset[5]
        
        print("Path: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + ", Dice: "+str(round(valor_dice.item(), 4))+" Iou :" + str(round(valor_iou.item(), 4)))
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        # Insert data to dicts for plotting stats later
        dice_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_dice.item())
        iou_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_iou.item())

        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        #Mostramos imagen, mascara y mascara predicha
        """
        item_x = cv2.resize(item_x.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        item_label = cv2.resize(item_label.astype(np.uint8), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)   
        mascara_predicha = cv2.resize(mascara_predicha.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        fig, (axs0, axs1, axs2) = plt.subplots(1,3, figsize = (15,15))
        axs0.imshow(item_x, interpolation='none', origin="lower")
        axs1.imshow(item_label, interpolation='none', origin="lower")
        axs2.imshow(mascara_predicha, interpolation='none', origin="lower")
        plt.show()
        """
        #guardar_imagen_plt(item_x, "item_x", i)
        #guardar_imagen_plt(item_label, "item_label", i)
        #guardar_imagen_plt(mascara_predicha, "mascara_predicha", i)
# Out:
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5211 Iou :0.6396
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6034 Iou :0.4682
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.2394 Iou :0.4697
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.589 Iou :0.455
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5766 Iou :0.4729
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7255 Iou :0.6549
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7188 Iou :0.6765
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.717 Iou :0.6032
# MAG_STREAM_PERCENTAGE: 0.01833621340669005->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7045 Iou :0.5741
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8674 Iou :0.833
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5516 Iou :0.6725
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6904 Iou :0.6554
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5338 Iou :0.75
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5016 Iou :0.7248
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.621 Iou :0.8293
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5714 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6094 Iou :0.907
# MAG_STREAM_PERCENTAGE: 0.0440294841841505->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6731 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0796 Iou :0.0857
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.3347 Iou :0.383
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.1045 Iou :0.15
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.2981 Iou :0.3382
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.3016 Iou :0.375
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.3671 Iou :0.4085
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5086 Iou :0.5221
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6371 Iou :0.5302
# MAG_STREAM_PERCENTAGE: 0.016127141527013274->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.626 Iou :0.4583
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4725 Iou :0.3474
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0548 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7305 Iou :0.7687
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.1762 Iou :0.339
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.57 Iou :0.686
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5577 Iou :0.8286
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2892 Iou :0.6
# MAG_STREAM_PERCENTAGE: 0.03353350043295439->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6204 Iou :0.8571
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6648 Iou :0.7564
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5356 Iou :0.9126
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6417 Iou :0.8556
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5603 Iou :0.9114
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6784 Iou :0.8788
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7448 Iou :0.8852
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8113 Iou :0.7818
# MAG_STREAM_PERCENTAGE: 0.012617992076316979->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8431 Iou :0.7288
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5051 Iou :0.3421
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5355 Iou :0.4
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5499 Iou :0.4218
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6491 Iou :0.5522
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6761 Iou :0.5455
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6542 Iou :0.8974
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4878 Iou :0.6452
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.381 Iou :0.5
# MAG_STREAM_PERCENTAGE: 0.0051881039780354785->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_104_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3692 Iou :0.3529
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.537 Iou :0.4038
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.3584 Iou :0.2548
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.3483 Iou :0.2514
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8162 Iou :0.75
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7517 Iou :0.6987
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6667 Iou :0.6071
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6629 Iou :0.5
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5484 Iou :0.425
# MAG_STREAM_PERCENTAGE: 0.013439222788093726->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_105_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6429 Iou :0.4932
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8634 Iou :0.7719
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7135 Iou :0.5546
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7097 Iou :0.55
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7518 Iou :0.7465
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.767 Iou :0.7471
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.76 Iou :0.8172
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7606 Iou :0.8308
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7407 Iou :0.7692
# MAG_STREAM_PERCENTAGE: 0.031590565279067236->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_106_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.75 Iou :0.75
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.2782 Iou :0.7558
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.1695 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5414 Iou :0.766
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5439 Iou :0.7209
# MAG_STREAM_PERCENTAGE: 0.022699011249845948->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3944 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8322 Iou :0.719
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8896 Iou :0.8739
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8594 Iou :0.8007
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8967 Iou :0.851
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8874 Iou :0.8071
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6515 Iou :0.9247
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7603 Iou :0.6765
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7117 Iou :0.9206
# MAG_STREAM_PERCENTAGE: 0.03954622238908128->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3564 Iou :0.9
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7065 Iou :0.958
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8767 Iou :0.9854
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8265 Iou :0.8265
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8149 Iou :0.8757
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8508 Iou :0.9052
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8306 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3954 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3469 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04625873565554406->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.1879 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8613 Iou :0.8135
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6918 Iou :0.5598
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7111 Iou :0.6275
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6938 Iou :0.5704
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6255 Iou :0.5176
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5232 Iou :0.4847
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3568 Iou :0.3363
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2828 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04542526664158644->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.1127 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8141 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8155 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7595 Iou :0.8233
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6753 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.652 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6287 Iou :0.9922
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3608 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3212 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046376833838882664->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.4074 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.1213 Iou :0.1573
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0495 Iou :0.1256
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.1339 Iou :0.1085
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.1813 Iou :0.2193
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0497 Iou :0.0606
# MAG_STREAM_PERCENTAGE: 0.00512032450044905->1%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0429 Iou :0.0667
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5787 Iou :0.535
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.55 Iou :0.3793
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5884 Iou :0.4211
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.4187 Iou :0.284
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.585 Iou :0.4134
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.2459 Iou :0.1818
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.4228 Iou :0.4561
# MAG_STREAM_PERCENTAGE: 0.029497971112781914->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_112_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3111 Iou :0.2561
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6046 Iou :0.8033
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5975 Iou :0.852
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4163 Iou :0.9761
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3951 Iou :0.9559
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8314 Iou :0.7915
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.2843 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0943 Iou :0.8333
# MAG_STREAM_PERCENTAGE: 0.02263170409723193->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_113_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.3734 Iou :0.5678
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.2462 Iou :0.3571
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4715 Iou :0.5232
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7195 Iou :0.6447
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.4865 Iou :0.5031
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6171 Iou :0.8308
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5042 Iou :0.7317
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3516 Iou :0.5714
# MAG_STREAM_PERCENTAGE: 0.01769842680318354->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_114_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3836 Iou :0.6087
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7279 Iou :0.9467
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6851 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7321 Iou :0.9804
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6325 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5434 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8505 Iou :0.9412
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7811 Iou :0.8349
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7606 Iou :0.7043
# MAG_STREAM_PERCENTAGE: 0.023459305016309127->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_115_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.703 Iou :0.5868
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5856 Iou :0.8025
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4088 Iou :0.7386
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.4681 Iou :0.6
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5062 Iou :0.82
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.2609 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4138 Iou :0.7059
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.011234103243831542->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_116_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4688 Iou :0.4413
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0138 Iou :0.0267
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.2737 Iou :0.2451
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.566 Iou :0.5469
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.477 Iou :0.5092
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.3112 Iou :0.2609
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3978 Iou :0.4286
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.1235 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03803299391115095->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_117_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.2919 Iou :0.4708
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6478 Iou :0.9868
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3398 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.1827 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6353 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6259 Iou :0.9583
# MAG_STREAM_PERCENTAGE: 0.023644503632137038->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_118_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6393 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8005 Iou :0.7786
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8639 Iou :0.8771
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8468 Iou :0.8027
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7733 Iou :0.9797
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.67 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8231 Iou :0.9167
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7902 Iou :0.9529
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6575 Iou :0.9057
# MAG_STREAM_PERCENTAGE: 0.04477182222240599->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_119_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6471 Iou :0.8462
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7334 Iou :0.6865
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4677 Iou :0.4677
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.3166 Iou :0.4713
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5326 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.732 Iou :0.9492
# MAG_STREAM_PERCENTAGE: 0.04327188682946441->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_11_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8 Iou :0.8966
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5855 Iou :0.7386
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6308 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2524 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03146277057472323->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_120_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.4752 Iou :0.75
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7431 Iou :0.9097
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5107 Iou :0.4142
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.573 Iou :0.5074
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.516 Iou :0.4119
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.52 Iou :0.4023
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6054 Iou :0.4956
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7638 Iou :0.736
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5438 Iou :0.6146
# MAG_STREAM_PERCENTAGE: 0.028685870834311428->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_121_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3286 Iou :0.5476
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.733 Iou :0.951
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6121 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6824 Iou :0.9898
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0362 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2191 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.4113 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.413 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.04531808054904121->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_122_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4134 Iou :0.3704
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5303 Iou :0.3711
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4384 Iou :0.382
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.4188 Iou :0.404
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.4433 Iou :0.45
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7317 Iou :0.7031
# MAG_STREAM_PERCENTAGE: 0.011406686067784362->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_123_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6237 Iou :0.4531
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8556 Iou :0.838
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.1267 Iou :0.1473
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.696 Iou :0.6507
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6189 Iou :0.5053
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6301 Iou :0.4599
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6471 Iou :0.5593
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5955 Iou :0.4649
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.1667 Iou :0.1944
# MAG_STREAM_PERCENTAGE: 0.016820097147017963->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_124_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0606 Iou :0.087
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5747 Iou :0.9887
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5571 Iou :0.4643
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4855 Iou :0.6634
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.1391 Iou :0.2
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.0423 Iou :0.0652
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5441 Iou :0.5068
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_125_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3235 Iou :0.5
# MAG_STREAM_PERCENTAGE: 0.027455847224822763->3%
# ...
# Magnitud: 0.6, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.03704439854626332->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3368 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.03704439854626332->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.2895 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8445 Iou :0.9828
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.9205 Iou :0.9903
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.936 Iou :0.9477
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8415 Iou :0.7914
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8359 Iou :0.8488
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8476 Iou :0.8018
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6403 Iou :0.757
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5109 Iou :0.662
# MAG_STREAM_PERCENTAGE: 0.04197236610122508->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.443 Iou :0.5593
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6472 Iou :0.4883
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6925 Iou :0.6009
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7816 Iou :0.6755
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5776 Iou :0.5447
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6258 Iou :0.5543
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7184 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7191 Iou :0.7805
# MAG_STREAM_PERCENTAGE: 0.043707844281195896->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.2759 Iou :0.381
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4512 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.1508 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.239 Iou :0.8636
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5156 Iou :0.5524
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5189 Iou :0.7971
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.557 Iou :0.6111
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5743 Iou :0.7632
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.4533 Iou :0.7083
# MAG_STREAM_PERCENTAGE: 0.023859868102511093->3%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.459 Iou :0.6667
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8094 Iou :0.7213
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5521 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7584 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6585 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6644 Iou :0.8673
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7899 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.759 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.044541303997628866->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8369 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6885 Iou :0.8546
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7516 Iou :0.739
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8085 Iou :0.7188
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6278 Iou :0.5596
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8154 Iou :0.7697
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7674 Iou :0.6612
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7745 Iou :0.7913
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3662 Iou :0.65
# MAG_STREAM_PERCENTAGE: 0.017232718930108738->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.2453 Iou :0.5417
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6299 Iou :0.9917
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.3736 Iou :0.9189
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5868 Iou :0.9245
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6257 Iou :0.9655
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6957 Iou :0.8889
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5983 Iou :0.7292
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5581 Iou :0.9231
# MAG_STREAM_PERCENTAGE: 0.030228250803545742->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.5 Iou :0.75
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.01 Iou :0.0566
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.3086 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.2086 Iou :0.7632
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5085 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.304 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5195 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5079 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2162 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.014521212357706712->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.2609 Iou :1.0
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.9166 Iou :0.8663
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7844 Iou :0.6783
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8209 Iou :0.699
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.9194 Iou :0.8879
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8178 Iou :0.6969
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8905 Iou :0.9266
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.6_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7132 Iou :0.7841
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.8_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7176 Iou :0.9307
# MAG_STREAM_PERCENTAGE: 0.046810771585707435->5%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7812 Iou :0.8197
# MAG_STREAM_PERCENTAGE: 0.03179077357670542->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4297 Iou :0.352
# MAG_STREAM_PERCENTAGE: 0.03179077357670542->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6023 Iou :0.8548
# MAG_STREAM_PERCENTAGE: 0.03179077357670542->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7529 Iou :0.6772
# MAG_STREAM_PERCENTAGE: 0.03179077357670542->4%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.4634 Iou :0.5067
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.05_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5041 Iou :0.9863
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.15_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7123 Iou :0.8228
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.1_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5233 Iou :0.9266
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.25_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6562 Iou :0.7434
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.2_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5654 Iou :0.6897
# MAG_STREAM_PERCENTAGE: 0.014958785192717596->2%
# Path: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.4_NISP_J_in_EUC_NIR_J_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7122 Iou :0.7526

# %%
dice_test_medio_total=dice_medio_test/pasos_test
print("Dice_medio_total="+str(dice_test_medio_total))
# Out:
# Dice_medio_total=0.506182130098688

# %%
iou_test_medio_total=iou_medio_test/pasos_test
print("IOU_medio_total="+str(iou_test_medio_total))
# Out:
# IOU_medio_total=0.605847661234087

# %%
# Filtrar NaNs y calcular la media para resultados_dice
dices_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_dice.values()]
print(dices_medios_por_magnitud)
# Filtrar NaNs y calcular la media para resultados_iou
ious_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_iou.values()]
print(ious_medios_por_magnitud)
# Out:
# [0.5469138130376284, 0.5293918805777202, 0.5084287783730045, 0.514548386710536, 0.5143621569584469, 0.5192848253326539, 0.5186548285939275, 0.4721055129255624, 0.4265448598659293]
# [0.6075745954206495, 0.5989705612836171, 0.5830791583612337, 0.6103553723430994, 0.6001226530424532, 0.653011977710785, 0.6382644612817688, 0.6085810576927194, 0.5523052181909109]

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in dices_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(dices_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('NISP J Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('Dice', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_1430072/3379223844.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in ious_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(ious_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('NISP J Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('IOU', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_1430072/1371107044.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# %%
matrix_data_dice = {redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
               for redshift, subdict in dice_results_redshift_with_mag_stream_percentage.items()}

labels_redshift = ['0.05','0.1','0.15','0.2','0.25','0.4','0.6','0.8','1']
labels_mag_percentage = ['1%','2%','3%','4%','5%']

# Convertir los datos en un DataFrame de Pandas
matrix_for_df = []
for redshift in labels_redshift:
    row = []
    for i, mag_label in enumerate(labels_mag_percentage, 1):  # 1, 2, 3, 4, 5
        if redshift in matrix_data_dice and i in matrix_data_dice[redshift]:
            row.append(matrix_data_dice[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Crear DataFrame
df = pd.DataFrame(matrix_for_df, index=labels_redshift, columns=labels_mag_percentage)

print(df)
# Crear el heatmap con anotaciones
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'Dice'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("NISP J Dice performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.160224  0.470743  0.589260  0.696446  0.703644
# 0.1   0.182612  0.504191  0.587915  0.625328  0.647648
# 0.15  0.181978  0.530557  0.578982  0.579461  0.572538
# 0.2   0.199634  0.539969  0.534828  0.600087  0.601210
# 0.25  0.205797  0.527658  0.534760  0.641417  0.572595
# 0.4   0.282873  0.572648  0.466000  0.620887  0.578061
# 0.6   0.357245  0.515428  0.501776  0.627993  0.546577
# 0.8   0.314922  0.435572  0.496727  0.558745  0.519639
# 1     0.305106  0.393703  0.432798  0.488093  0.484349

# %%
matrix_data_iou = {redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
               for redshift, subdict in iou_results_redshift_with_mag_stream_percentage.items()}

labels_redshift = ['0.05','0.1','0.15','0.2','0.25','0.4','0.6','0.8','1']
labels_mag_percentage = ['1%','2%','3%','4%','5%']

# Convertir los datos en un DataFrame de Pandas
matrix_for_df = []
for redshift in labels_redshift:
    row = []
    for i, mag_label in enumerate(labels_mag_percentage, 1):  # 1, 2, 3, 4, 5
        if redshift in matrix_data_iou and i in matrix_data_iou[redshift]:
            row.append(matrix_data_iou[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Crear DataFrame
df = pd.DataFrame(matrix_for_df, index=labels_redshift, columns=labels_mag_percentage)

print(df)
# Crear el heatmap con anotaciones
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'IoU'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("NISP J Intersection over union performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.218509  0.536247  0.706457  0.739155  0.724149
# 0.1   0.261881  0.578183  0.685751  0.655202  0.717445
# 0.15  0.166166  0.597898  0.642399  0.660466  0.722325
# 0.2   0.228683  0.618499  0.674647  0.659246  0.757352
# 0.25  0.227958  0.577405  0.635232  0.762893  0.694895
# 0.4   0.291251  0.638992  0.708762  0.759390  0.764741
# 0.6   0.381226  0.562829  0.682531  0.756217  0.742569
# 0.8   0.352310  0.508635  0.660873  0.738721  0.728509
# 1     0.361299  0.440924  0.569883  0.691436  0.659837
