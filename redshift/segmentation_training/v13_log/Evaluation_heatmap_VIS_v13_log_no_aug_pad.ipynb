# %%
import copy
import cv2
import glob
import math
import matplotlib.pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import numpy as np
import os
import pandas as pd
import seaborn as sns
from astropy.io import fits
import torch
from torch.utils.data import Dataset
from torchmetrics import Dice
from torchmetrics import Dice, JaccardIndex
import segmentation_models_pytorch as smp

# %%
hiperparametros = {'nombre_notebook': 'Evaluation_VIS_1000imgs_v13_log_no_aug.ipynb',
                    'nombre_experimento' : 'Evaluation_VIS_1000imgs_v13_log_no_aug_pad',
                    'nombre_mejor_modelo_entrenado' : 'VIS_1000imgs_v13_log_pad',
                    'device' : torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
                    'ruta_galaxias' : 'galaxies_test_VIS/galaxy_and_stream_convolved*.fits',
                    'ruta_mascaras' : '../masks_train_VIS/mask_',
                    'ancho_imagen_original' : 600,
                    'alto_imagen_original' : 600,
                    'ancho_imagen_deseado' : 608,
                    'alto_imagen_deseado' : 608}

# %%
def pad_to_size(image, target_h, target_w, pad_value=0):
    """Hace padding para alcanzar el tamaño deseado sin deformar"""
    h, w = image.shape[:2]
    pad_h = target_h - h
    pad_w = target_w - w
    
    # Padding simétrico
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    
    if len(image.shape) == 2:  # Para máscaras
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right)), 
                     mode='constant', constant_values=pad_value)
    else:  # Para imágenes RGB
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right), (0, 0)), 
                     mode='constant', constant_values=pad_value)

# %%
def get_galaxy_number(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[4]

def get_galaxy_magnitude(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[5]

def normalize_01(inp: np.ndarray):
    """Squash image input to the value range [0, 1] (no clipping)"""
    inp_out = (inp - np.min(inp)) / np.ptp(inp)
    return inp_out

def imagen_logaritmica(img: np.ndarray)->np.ndarray:
    """
    Escalamos de forma logarítmica la imagen para aumentar el contraste
    """
    img_log = np.log(img, where=(img>0))
    valor_minimo = np.min(img_log)
    np.putmask(img_log, img!=0, img_log+abs(valor_minimo))
    return img_log

# %%
def get_mag_stream_percentage(galaxy_number):
    
    path_catalogs_folder = "../../dataset_generation/catalogs_for_checking" 
    path_catalog = os.path.join(path_catalogs_folder, "stream_characteristics_"+str(galaxy_number)+".txt")
    df = pd.read_csv(path_catalog, delimiter=r"\s+", engine="python")
    mag_bulge = df.iloc[1, 3]
    mag_disk = df.iloc[1, 8]
    mag_stream = df.iloc[1, 13]
    zeropoint= 30.132  # For VIS, (For NISP is 30)
    flux_bulge = 10**((mag_bulge-zeropoint)/(-2.5)) 
    flux_disk = 10**((mag_disk-zeropoint)/(-2.5))
    flux_galaxy = flux_bulge + flux_disk
    flux_stream = 10**((mag_stream-zeropoint)/(-2.5)) 
    mag_stream_percentage = flux_stream/flux_galaxy
    mag_stream_percentage_rounded_up = math.ceil(mag_stream_percentage*100)
    if mag_stream_percentage_rounded_up == 6:
        mag_stream_percentage_rounded_up = 5
    #print("MAG_STREAM_PERCENTAGE: " + str(mag_stream_percentage) + "->" + str(mag_stream_percentage_rounded_up)+ "%")
    return mag_stream_percentage_rounded_up

# %%
def get_distance_to_galaxy_center(galaxy_number):
    path_catalogs_folder = "../../dataset_generation/catalogs_for_checking" 
    path_catalog = os.path.join(path_catalogs_folder, "stream_characteristics_"+str(galaxy_number)+".txt")
    df = pd.read_csv(path_catalog, delimiter=r"\s+", engine="python")
    distance_to_galaxy_center = df.iloc[1,14]
    #print("RR_STREAM: " + str(distance_to_galaxy_center))
    return distance_to_galaxy_center

# %%
class MyDataset(Dataset):
    """
    Dataset básico sin ningún tipo de augmentation
    """
    def __init__(self, galaxias_con_colas_de_marea, transform=None):
        """
        Constructor del dataset
        @param galaxias_con_colas_de_marea: Lista de rutas a los ficheros que contienen los datos de las galaxias
        """
        self.galaxias_con_colas_de_marea = galaxias_con_colas_de_marea
        self.transform=transform

    def __getitem__(self, index):
        #Abrimos la imagen de la galaxia con cola de marea
        ruta = self.galaxias_con_colas_de_marea[index]
        magnitud_real = get_galaxy_magnitude(ruta)
        
        galaxy_fits = fits.open(self.galaxias_con_colas_de_marea[index])
        x = galaxy_fits[0].data.astype(np.float32)
        #Abrimos la mascara correspondiente a la imagen
        numero_galaxia = get_galaxy_number(self.galaxias_con_colas_de_marea[index])
        magnitud_galaxia = get_galaxy_magnitude(self.galaxias_con_colas_de_marea[index])
        mag_stream_percentage = get_mag_stream_percentage(numero_galaxia)
        distance_to_galaxy_center = get_distance_to_galaxy_center(numero_galaxia)
        y = np.array(cv2.imread(hiperparametros['ruta_mascaras']+str(numero_galaxia)+"_"+str(magnitud_galaxia)+".png",0)).astype(np.float32)
        #x = normalize_01(x)
        x_tensor_visualizar = copy.deepcopy(x)
        x = imagen_logaritmica(x)

        x = normalize_01(x)

        x = pad_to_size(x, hiperparametros['alto_imagen_deseado'], hiperparametros['ancho_imagen_deseado'])
        y = pad_to_size(y, hiperparametros['alto_imagen_deseado'], hiperparametros['ancho_imagen_deseado'])
        if(self.transform is not None):
            augmented = self.transform(image=x, mask=y)
            x_tensor= augmented["image"]
            y_tensor= augmented["mask"].long()
        else:
            x_tensor = torch.from_numpy(x).float()
            x_tensor=torch.unsqueeze(x_tensor, dim=0)
            y_tensor = torch.from_numpy(y).long()
        
        #Hacemos reshape de los tensores
        y_tensor=torch.unsqueeze(y_tensor, dim=0)
        return x_tensor, y_tensor, ruta, magnitud_real, x_tensor_visualizar, mag_stream_percentage, distance_to_galaxy_center
    
    def __len__(self):
        """
        Devuelve la longitud del dataset
        """
        return len(self.galaxias_con_colas_de_marea)

# %%
dice = Dice(num_classes=2, average='macro', ignore_index=0)
iou = JaccardIndex(task='multiclass', num_classes=2, average='none', ignore_index=0)
imagenes_test = glob.glob(hiperparametros['ruta_galaxias'])
imagenes_test.sort()
#Cargamos el dataset de test
test_dataset= MyDataset(imagenes_test)
print("Number of valid images: " + str(len(imagenes_test)))
device = hiperparametros['device']
#dice.to(device)
# Out:
# Number of valid images: 1798

# %%
unet = smp.Unet(
    encoder_name="resnet18",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
#Cargamos el modelo previamente entrenado
ruta_modelo = hiperparametros['nombre_mejor_modelo_entrenado']
mejor_modelo = unet
mejor_modelo.load_state_dict(torch.load(ruta_modelo))
mejor_modelo.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# ==========================================
# 1. DEFINICIÓN DE ESTRUCTURAS DE DATOS
# ==========================================
resultados_dice = {
    '0.05':[], '0.1':[], '0.15':[], '0.2':[], '0.25':[],
    '0.4':[], '0.6':[], '0.8':[], '1':[],
}
resultados_iou = {
    '0.05':[], '0.1':[], '0.15':[], '0.2':[], '0.25':[],
    '0.4':[], '0.6':[], '0.8':[], '1':[],
}

dice_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}

iou_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}

# NUEVAS ESTRUCTURAS PARA DISTANCIA
dice_results_redshift_with_distance = {
    '0.05':{}, '0.1':{}, '0.15':{}, '0.2':{}, '0.25':{},
    '0.4':{}, '0.6':{}, '0.8':{}, '1':{},
}

iou_results_redshift_with_distance = {
    '0.05':{}, '0.1':{}, '0.15':{}, '0.2':{}, '0.25':{},
    '0.4':{}, '0.6':{}, '0.8':{}, '1':{},
}

# ==========================================
# CALCULAR BINS AUTOMÁTICAMENTE
# ==========================================
print("Calculando rango de distancias del dataset...")

# Recopilar todas las distancias del dataset
all_distances = []
for i in range(len(test_dataset)):
    item = test_dataset.__getitem__(i)
    all_distances.append(item[6])

# Calcular mínimo y máximo
min_distance = min(all_distances)
max_distance = max(all_distances)

print(f"Distancia mínima: {min_distance:.2f}")
print(f"Distancia máxima: {max_distance:.2f}")

# Redondear para tener límites enteros
import math
min_distance_rounded = math.floor(min_distance)  # Redondear hacia abajo
max_distance_rounded = math.ceil(max_distance)   # Redondear hacia arriba

# Crear 5 intervalos iguales
num_bins = 5
bin_width = (max_distance_rounded - min_distance_rounded) / num_bins

# Generar los bins
distance_bins = [min_distance_rounded + i * bin_width for i in range(num_bins + 1)]
# Redondear cada bin a entero
distance_bins = [round(b) for b in distance_bins]

# Crear las etiquetas
distance_labels = [f"{distance_bins[i]}-{distance_bins[i+1]}" for i in range(num_bins)]

print(f"\nBins de distancia creados: {distance_bins}")
print(f"Etiquetas: {distance_labels}")

# ==========================================
# 2. EVALUACIÓN EN TEST DATASET
# ==========================================
ancho = hiperparametros['ancho_imagen_deseado']
alto = hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test = 0
dice_medio_test = 0
iou_medio_test = 0
zp = 23.896
pix_scale = 0.1

for i in range(int(len(test_dataset)*0.01)):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    x_tensor_visualizar = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    
    # Si la máscara es vacía no intentamos segmentarla
    if(np.count_nonzero(item_label)!=0):
        # Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))[1]
        
        magnitud = item_dataset[3]
        mag_stream_percentage = item_dataset[5]
        distance_to_galaxy_center = item_dataset[6]
        
        print("Path: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + 
              ", Dice: "+str(round(valor_dice.item(), 4))+" Iou :" + str(round(valor_iou.item(), 4))+
              ", Distance: "+str(round(distance_to_galaxy_center, 2)))
        
        # Almacenar en estructuras existentes
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_dice.item())
        iou_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_iou.item())
        
        # NUEVO: Determinar bin de distancia y almacenar
        distance_bin_idx = None
        for idx in range(len(distance_bins) - 1):
            if distance_bins[idx] <= distance_to_galaxy_center < distance_bins[idx + 1]:
                distance_bin_idx = idx
                break
        
        # Caso especial: si es exactamente el valor máximo
        if distance_to_galaxy_center == distance_bins[-1]:
            distance_bin_idx = len(distance_bins) - 2
        
        if distance_bin_idx is not None:
            distance_label = distance_labels[distance_bin_idx]
            
            # Inicializar si no existe
            if distance_label not in dice_results_redshift_with_distance[magnitud]:
                dice_results_redshift_with_distance[magnitud][distance_label] = []
                iou_results_redshift_with_distance[magnitud][distance_label] = []
            
            # Añadir resultados
            dice_results_redshift_with_distance[magnitud][distance_label].append(valor_dice.item())
            iou_results_redshift_with_distance[magnitud][distance_label].append(valor_iou.item())
        
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        
        #Mostramos imagen, mascara y mascara predicha
        item_x = item_x.astype(np.float32)   
        item_label = item_label.astype(np.uint8)
        mascara_predicha = mascara_predicha.astype(np.float32)  

        # Quitar el padding al mostrar
        crop = 4
        item_x = item_x[crop:-crop, crop:-crop]
        item_label = item_label[crop:-crop, crop:-crop]
        mascara_predicha = mascara_predicha[crop:-crop, crop:-crop]

        x_tensor_visualizar = x_tensor_visualizar[crop:-crop, crop:-crop]
        zeros = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        ones = np.ones((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))

        cmap = colors.ListedColormap(['rebeccapurple', 'yellow', 'crimson', 'lime'])
        bounds=[0,1,2,3,4]
        norm = colors.BoundaryNorm(bounds, cmap.N)
        dif = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        dif[ ( item_label == zeros ) & (mascara_predicha == zeros) ] = 0
        dif[ (item_label == ones ) & (mascara_predicha == ones) ] = 1
        dif[ (item_label == zeros) & (mascara_predicha == ones) ] = 2
        dif[ (item_label == ones) & (mascara_predicha == zeros)] = 3

        fig, (axs0, axs1, axs2, axs3) = plt.subplots(1, 4, figsize=(15, 15))

        sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))

        # Filtrar inf y nan para calcular los límites
        sb_valid = sb_array[np.isfinite(sb_array)]
        min_sb = np.min(sb_valid)
        max_sb = np.max(sb_valid)

        print("min_sb: "+ str(min_sb))
        print("max_sb: "+ str(max_sb))
        # Usar axs0 en lugar de plt
        imshow_img = axs0.imshow(sb_array, origin='lower', interpolation="none", cmap="viridis_r", vmin=max_sb, vmax=min_sb)
        cb = fig.colorbar(imshow_img, ax=axs0, fraction=0.046, pad=0.04)
        cb.set_label(r'Surface brightness [mag/arcsec$^{2}$]')

        # Usar axs0.transData en lugar de plt.gca().transData
        scalebar = AnchoredSizeBar(axs0.transData, 10./pix_scale, "10 arcsec", borderpad=1.0, sep=5, loc="lower right", pad=0.5, color="blue", frameon=True, size_vertical=3)
        axs0.add_artist(scalebar)

        axs1.imshow(item_label, interpolation='none', origin="lower")
        axs2.imshow(mascara_predicha, interpolation='none', origin="lower", cmap="plasma")
        axs2.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs2.transAxes)
        axs3.imshow(dif, interpolation='none', origin="lower", cmap=cmap, norm=norm)
        axs3.text(0.05, 0.95, "IOU: "+str(round(valor_iou.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs3.transAxes)
        plt.subplots_adjust(wspace=0.7)
        plt.show()
# Out:
# Calculando rango de distancias del dataset...
# Distancia mínima: 2.00
# Distancia máxima: 39.67
#
# Bins de distancia creados: [2, 10, 17, 25, 32, 40]
# Etiquetas: ['2-10', '10-17', '17-25', '25-32', '32-40']
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6704 Iou :0.5335, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.71348
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8146 Iou :0.8606, Distance: 24.0
# min_sb: 18.896
# max_sb: 120.697495
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7595 Iou :0.7145, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.780426
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5202 Iou :0.7357, Distance: 24.0
# min_sb: 18.896
# max_sb: 21.271488
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7879 Iou :0.8587, Distance: 24.0
# min_sb: 18.896
# max_sb: 21.269924
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7126 Iou :0.7088, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.848093
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5657 Iou :0.5351, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.914015
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6089 Iou :0.6426, Distance: 24.0
# min_sb: 18.896
# max_sb: 120.7052
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.5687 Iou :0.5556, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.540462
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.738 Iou :0.5903, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.869875
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7818 Iou :0.6985, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.51491
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8344 Iou :0.739, Distance: 12.0
# min_sb: 18.896
# max_sb: 21.017044
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7826 Iou :0.7255, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.504658
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7987 Iou :0.6925, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.921207
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7532 Iou :0.8547, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.794588
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.1255 Iou :0.7333, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.78716
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0084 Iou :0.0241, Distance: 12.0
# min_sb: 18.896
# max_sb: 21.252823
# /tmp/ipykernel_1961066/2428534037.py:179: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_visualizar) + zp + (5 * np.log10(pix_scale))

# %%
# ==========================================
# 1. DEFINICIÓN DE ESTRUCTURAS DE DATOS
# ==========================================
resultados_dice = {
    '0.05':[], '0.1':[], '0.15':[], '0.2':[], '0.25':[],
    '0.4':[], '0.6':[], '0.8':[], '1':[],
}
resultados_iou = {
    '0.05':[], '0.1':[], '0.15':[], '0.2':[], '0.25':[],
    '0.4':[], '0.6':[], '0.8':[], '1':[],
}

dice_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}

iou_results_redshift_with_mag_stream_percentage = {
    '0.05':{1:[],2:[],3:[],4:[],5:[],},
    '0.1':{1:[],2:[],3:[],4:[],5:[],},
    '0.15':{1:[],2:[],3:[],4:[],5:[],},
    '0.2':{1:[],2:[],3:[],4:[],5:[],},
    '0.25':{1:[],2:[],3:[],4:[],5:[],},
    '0.4':{1:[],2:[],3:[],4:[],5:[],},
    '0.6':{1:[],2:[],3:[],4:[],5:[],},
    '0.8':{1:[],2:[],3:[],4:[],5:[],},
    '1':{1:[],2:[],3:[],4:[],5:[],},
}

# NUEVAS ESTRUCTURAS PARA DISTANCIA
dice_results_redshift_with_distance = {
    '0.05':{}, '0.1':{}, '0.15':{}, '0.2':{}, '0.25':{},
    '0.4':{}, '0.6':{}, '0.8':{}, '1':{},
}

iou_results_redshift_with_distance = {
    '0.05':{}, '0.1':{}, '0.15':{}, '0.2':{}, '0.25':{},
    '0.4':{}, '0.6':{}, '0.8':{}, '1':{},
}

# ==========================================
# CALCULAR BINS AUTOMÁTICAMENTE
# ==========================================
print("Calculando rango de distancias del dataset...")

# Recopilar todas las distancias del dataset
all_distances = []
for i in range(len(test_dataset)):
    item = test_dataset.__getitem__(i)
    all_distances.append(item[6])

# Calcular mínimo y máximo
min_distance = min(all_distances)
max_distance = max(all_distances)

print(f"Distancia mínima: {min_distance:.2f}")
print(f"Distancia máxima: {max_distance:.2f}")

# Redondear para tener límites enteros
import math
min_distance_rounded = math.floor(min_distance)  # Redondear hacia abajo
max_distance_rounded = math.ceil(max_distance)   # Redondear hacia arriba

# Crear 5 intervalos iguales
num_bins = 5
bin_width = (max_distance_rounded - min_distance_rounded) / num_bins

# Generar los bins
distance_bins = [min_distance_rounded + i * bin_width for i in range(num_bins + 1)]
# Redondear cada bin a entero
distance_bins = [round(b) for b in distance_bins]

# Crear las etiquetas
distance_labels = [f"{distance_bins[i]}-{distance_bins[i+1]}" for i in range(num_bins)]

print(f"\nBins de distancia creados: {distance_bins}")
print(f"Etiquetas: {distance_labels}")

# ==========================================
# 2. EVALUACIÓN EN TEST DATASET
# ==========================================
ancho = hiperparametros['ancho_imagen_deseado']
alto = hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test = 0
dice_medio_test = 0
iou_medio_test = 0
zp = 29.9
pix_scale = 0.1

for i in range(int(len(test_dataset))):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    x_tensor_visualizar = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    
    # Si la máscara es vacía no intentamos segmentarla
    if(np.count_nonzero(item_label)!=0):
        # Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))[1]
        
        magnitud = item_dataset[3]
        mag_stream_percentage = item_dataset[5]
        distance_to_galaxy_center = item_dataset[6]
        
        print("Path: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + 
              ", Dice: "+str(round(valor_dice.item(), 4))+" Iou :" + str(round(valor_iou.item(), 4))+
              ", Distance: "+str(round(distance_to_galaxy_center, 2)))
        
        # Almacenar en estructuras existentes
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_dice.item())
        iou_results_redshift_with_mag_stream_percentage[magnitud][mag_stream_percentage].append(valor_iou.item())
        
        # NUEVO: Determinar bin de distancia y almacenar
        distance_bin_idx = None
        for idx in range(len(distance_bins) - 1):
            if distance_bins[idx] <= distance_to_galaxy_center < distance_bins[idx + 1]:
                distance_bin_idx = idx
                break
        
        # Caso especial: si es exactamente el valor máximo
        if distance_to_galaxy_center == distance_bins[-1]:
            distance_bin_idx = len(distance_bins) - 2
        
        if distance_bin_idx is not None:
            distance_label = distance_labels[distance_bin_idx]
            
            # Inicializar si no existe
            if distance_label not in dice_results_redshift_with_distance[magnitud]:
                dice_results_redshift_with_distance[magnitud][distance_label] = []
                iou_results_redshift_with_distance[magnitud][distance_label] = []
            
            # Añadir resultados
            dice_results_redshift_with_distance[magnitud][distance_label].append(valor_dice.item())
            iou_results_redshift_with_distance[magnitud][distance_label].append(valor_iou.item())
        
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
# Out:
# Calculando rango de distancias del dataset...
# Distancia mínima: 2.00
# Distancia máxima: 39.67
#
# Bins de distancia creados: [2, 10, 17, 25, 32, 40]
# Etiquetas: ['2-10', '10-17', '17-25', '25-32', '32-40']
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6704 Iou :0.5335, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8146 Iou :0.8606, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7595 Iou :0.7145, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5202 Iou :0.7357, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7879 Iou :0.8587, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7126 Iou :0.7088, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.5657 Iou :0.5351, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6089 Iou :0.6426, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.5687 Iou :0.5556, Distance: 24.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.738 Iou :0.5903, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7818 Iou :0.6985, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8344 Iou :0.739, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7826 Iou :0.7255, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7987 Iou :0.6925, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7532 Iou :0.8547, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.1255 Iou :0.7333, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0084 Iou :0.0241, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 12.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.2457 Iou :0.9944, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3085 Iou :0.7102, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2557 Iou :0.9313, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.2794 Iou :0.4865, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3875 Iou :0.5321, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0367 Iou :0.0938, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0391 Iou :0.1064, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.2265 Iou :0.3033, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.2981 Iou :0.2503, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.2727 Iou :0.2541, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.454 Iou :0.3495, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2592 Iou :0.2183, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0029 Iou :0.0025, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.2187 Iou :0.1511, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 39.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8049 Iou :0.7911, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7123 Iou :0.9379, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7584 Iou :0.9144, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8847 Iou :0.9637, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.888 Iou :0.9721, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8959 Iou :0.9494, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.838 Iou :0.8688, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7987 Iou :0.7568, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7973 Iou :0.7682, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8282 Iou :0.9531, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7368 Iou :0.6359, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8532 Iou :0.7464, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6265 Iou :0.5025, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6663 Iou :0.4995, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6232 Iou :0.5471, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4343 Iou :0.4048, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.4959 Iou :0.4187, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.1689 Iou :0.1799, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.777 Iou :0.8867, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5427 Iou :0.8824, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.5341 Iou :0.8459, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5921 Iou :0.9479, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.637 Iou :0.9024, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0461 Iou :0.5238, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7874 Iou :0.9115, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5521 Iou :0.8548, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6632 Iou :0.8514, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7464 Iou :0.9961, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8859 Iou :0.9737, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7833 Iou :0.9984, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.9099 Iou :0.8772, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.9189 Iou :0.9761, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.9005 Iou :0.8387, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7167 Iou :0.7914, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6552 Iou :0.7854, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.5396 Iou :0.7415, Distance: 18.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.1698 Iou :0.9081, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7168 Iou :0.9321, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7895 Iou :0.9759, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.4408 Iou :1.0, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6639 Iou :0.9727, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.4656 Iou :0.9947, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4218 Iou :1.0, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.3583 Iou :1.0, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.4646 Iou :0.9388, Distance: 4.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.783 Iou :0.9968, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8907 Iou :0.9579, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8601 Iou :0.9911, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8566 Iou :0.8278, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8642 Iou :0.8518, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.9194 Iou :0.8696, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8935 Iou :0.8136, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8439 Iou :0.7796, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7269 Iou :0.6667, Distance: 26.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.1779 Iou :0.9163, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7232 Iou :0.9787, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6727 Iou :0.9721, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.792 Iou :0.9947, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7742 Iou :0.9837, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8002 Iou :1.0, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8046 Iou :1.0, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8577 Iou :1.0, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7665 Iou :1.0, Distance: 13.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7109 Iou :0.888, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7196 Iou :0.7337, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8127 Iou :0.7921, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7735 Iou :0.7722, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7073 Iou :0.7197, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8167 Iou :0.7779, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.9162 Iou :0.9153, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.9398 Iou :0.9349, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.9243 Iou :0.9043, Distance: 11.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6939 Iou :0.7801, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5336 Iou :1.0, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6452 Iou :0.9477, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5845 Iou :0.9049, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.501 Iou :0.9745, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5936 Iou :0.9116, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6188 Iou :0.9409, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7621 Iou :0.9229, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8138 Iou :0.9025, Distance: 13.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.0 Iou :0.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0 Iou :0.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0 Iou :0.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.0021 Iou :1.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.266 Iou :0.961, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.304 Iou :0.7217, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.3119 Iou :0.9903, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7384 Iou :0.9897, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7635 Iou :0.9981, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7123 Iou :0.9083, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7348 Iou :0.9182, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7732 Iou :0.8503, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8338 Iou :0.9251, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7481 Iou :0.9573, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.7124 Iou :0.9045, Distance: 33.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.1745 Iou :0.7597, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8191 Iou :0.9446, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7316 Iou :0.9695, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8727 Iou :0.7908, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8908 Iou :0.8631, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8201 Iou :0.695, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7474 Iou :0.5967, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6783 Iou :0.5132, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.657 Iou :0.4897, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5746 Iou :0.6612, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5992 Iou :0.5375, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6584 Iou :0.6021, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5077 Iou :0.4533, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6723 Iou :0.5399, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5559 Iou :0.4854, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6904 Iou :0.5741, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5514 Iou :0.4625, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6016 Iou :0.4611, Distance: 37.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.2447 Iou :0.8363, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7696 Iou :0.9383, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7345 Iou :0.9219, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6231 Iou :0.9645, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6237 Iou :0.9572, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.4486 Iou :1.0, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3942 Iou :1.0, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.4473 Iou :1.0, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3824 Iou :0.7324, Distance: 6.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0059 Iou :0.0162, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.2627 Iou :0.349, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0334 Iou :0.0783, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3882 Iou :0.3682, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2434 Iou :0.2805, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.2615 Iou :0.2256, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0 Iou :0.0, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6381 Iou :0.642, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.4495 Iou :0.4056, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.519 Iou :0.4511, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.2614 Iou :0.3509, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2308 Iou :0.2746, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.3754 Iou :0.5145, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4933 Iou :1.0, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6248 Iou :0.9704, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6958 Iou :0.9191, Distance: 4.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6707 Iou :0.9343, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5369 Iou :1.0, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4821 Iou :0.9799, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.2376 Iou :1.0, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2039 Iou :1.0, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5136 Iou :1.0, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7104 Iou :0.963, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.648 Iou :1.0, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_118_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.754 Iou :0.9744, Distance: 15.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.809 Iou :0.8536, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8949 Iou :0.8465, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.9172 Iou :0.8788, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.9125 Iou :0.9046, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.9071 Iou :0.9054, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8472 Iou :1.0, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.2771 Iou :1.0, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2403 Iou :1.0, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_119_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3278 Iou :1.0, Distance: 9.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.603 Iou :0.997, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6566 Iou :1.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8056 Iou :0.9991, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6983 Iou :1.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6911 Iou :1.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0367 Iou :1.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0 Iou :0.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_11_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 3.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8248 Iou :0.796, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6028 Iou :0.8602, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7095 Iou :0.7936, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7287 Iou :0.736, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7938 Iou :0.8174, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6069 Iou :0.6929, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6642 Iou :0.6335, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6528 Iou :0.6597, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_120_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6543 Iou :0.6795, Distance: 10.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6885 Iou :0.9946, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.4577 Iou :0.9109, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.3343 Iou :0.8625, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6433 Iou :0.9331, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5169 Iou :0.9496, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6285 Iou :1.0, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6937 Iou :1.0, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7959 Iou :0.9796, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_121_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.871 Iou :0.971, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5434 Iou :0.9313, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8217 Iou :0.9778, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7704 Iou :0.9634, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8447 Iou :0.9982, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8594 Iou :0.9914, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7182 Iou :1.0, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8589 Iou :0.9896, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8395 Iou :1.0, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_122_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6377 Iou :1.0, Distance: 18.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6394 Iou :0.5796, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6975 Iou :0.7245, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6245 Iou :0.5799, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5441 Iou :0.7115, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6901 Iou :0.7053, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.754 Iou :0.6083, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6703 Iou :0.6093, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6053 Iou :0.5328, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_123_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.4348 Iou :0.6452, Distance: 19.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.767 Iou :0.9474, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6973 Iou :0.9595, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6888 Iou :1.0, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3309 Iou :0.7083, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.3555 Iou :0.6643, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7269 Iou :0.6176, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8164 Iou :0.7596, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8156 Iou :0.7348, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_124_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6044 Iou :0.5787, Distance: 22.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.2631 Iou :0.9297, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.41 Iou :0.7063, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4805 Iou :0.7707, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6289 Iou :0.6071, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5481 Iou :0.6298, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.7853 Iou :0.8699, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7945 Iou :0.9932, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0229 Iou :1.0, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_125_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 15.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6905 Iou :0.9434, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7375 Iou :0.7928, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7123 Iou :0.7622, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7592 Iou :0.6474, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7396 Iou :0.7201, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6938 Iou :0.5794, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6804 Iou :0.6818, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_126_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 8.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5942 Iou :0.5265, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.4907 Iou :0.4615, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.1634 Iou :0.1918, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.5637 Iou :0.4831, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5653 Iou :0.4757, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5663 Iou :0.4303, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.4754 Iou :0.3268, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.361 Iou :0.2373, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_127_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.2515 Iou :0.1578, Distance: 3.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0564 Iou :0.6825, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5825 Iou :0.8817, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4577 Iou :0.8946, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3542 Iou :0.722, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.4967 Iou :0.826, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.2037 Iou :0.5, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0757 Iou :0.2091, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.139 Iou :0.2927, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_128_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0758 Iou :0.1553, Distance: 2.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7767 Iou :0.8274, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8006 Iou :0.9159, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7909 Iou :0.8108, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8156 Iou :0.8419, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8157 Iou :0.976, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8768 Iou :0.9073, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7646 Iou :0.9111, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6283 Iou :0.9227, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_129_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.058 Iou :1.0, Distance: 34.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.4823 Iou :0.997, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7332 Iou :0.9846, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6445 Iou :0.997, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7904 Iou :0.9773, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7571 Iou :0.9801, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8541 Iou :0.9934, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7981 Iou :1.0, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8535 Iou :0.9868, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_12_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8222 Iou :0.9875, Distance: 28.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6255 Iou :0.9937, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.4886 Iou :0.7854, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.2883 Iou :0.7973, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0464 Iou :0.1933, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.5683 Iou :0.8009, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.0183 Iou :0.7273, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.611 Iou :0.957, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6164 Iou :0.9357, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_130_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6129 Iou :0.93, Distance: 24.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8097 Iou :0.7809, Distance: 4.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7586 Iou :0.9953, Distance: 4.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7418 Iou :0.9672, Distance: 4.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# ...
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8232 Iou :0.9988, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.9015 Iou :0.9957, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8409 Iou :0.9876, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.9213 Iou :0.9685, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.838 Iou :0.9784, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8274 Iou :0.9795, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3516 Iou :1.0, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2774 Iou :1.0, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_26_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 11.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6286 Iou :0.9961, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.5454 Iou :1.0, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4593 Iou :1.0, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6474 Iou :1.0, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.4418 Iou :1.0, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8017 Iou :0.963, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7715 Iou :0.9191, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.7214 Iou :0.7652, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_270_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.6868 Iou :0.7375, Distance: 31.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5911 Iou :0.8948, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7909 Iou :0.7685, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6897 Iou :0.8311, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.7198 Iou :0.6887, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.654 Iou :0.6357, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6776 Iou :0.609, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.3071 Iou :0.3961, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.2074 Iou :0.3545, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_271_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.1792 Iou :0.3731, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.3169 Iou :0.9908, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7399 Iou :0.9569, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7026 Iou :0.9492, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.753 Iou :0.7461, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7506 Iou :0.8187, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8088 Iou :0.7328, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7949 Iou :0.7815, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.6211 Iou :0.7109, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_272_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.3975 Iou :0.6882, Distance: 19.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.8516 Iou :0.9416, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.7475 Iou :1.0, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.837 Iou :0.9824, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.6474 Iou :0.9982, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6616 Iou :0.9791, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.6315 Iou :1.0, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.8158 Iou :0.9845, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.8268 Iou :0.9286, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_273_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8502 Iou :0.9835, Distance: 21.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.5715 Iou :0.9411, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8618 Iou :0.9743, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8423 Iou :0.993, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8351 Iou :0.8754, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.8685 Iou :0.9206, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.8619 Iou :0.7848, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.9144 Iou :0.8752, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.886 Iou :0.8097, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8252 Iou :0.7248, Distance: 36.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6549 Iou :0.9961, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.1488 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.4909 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.0108 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.1413 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.1545 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.1922 Iou :0.9143, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0784 Iou :0.8333, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0521 Iou :0.6335, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.1849 Iou :0.7233, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0042 Iou :0.093, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.3959 Iou :0.7949, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.2465 Iou :0.7037, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5061 Iou :0.8993, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.0081 Iou :1.0, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.0 Iou :0.0, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 6.0
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.6977 Iou :0.973, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.8721 Iou :0.9662, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.8628 Iou :0.9598, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8332 Iou :0.8741, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.9103 Iou :0.9202, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.886 Iou :0.9287, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.9418 Iou :0.9346, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.9099 Iou :0.9196, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.8999 Iou :0.8275, Distance: 38.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.7778 Iou :0.836, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6141 Iou :1.0, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.7389 Iou :0.9956, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.8661 Iou :0.9764, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.7763 Iou :0.9944, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.858 Iou :0.9342, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.7155 Iou :0.7155, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.1014 Iou :1.0, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.0 Iou :0.0, Distance: 12.33
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0024 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.6855 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.6265 Iou :0.9835, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.4951 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.6112 Iou :1.0, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.5759 Iou :0.9778, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.6425 Iou :0.9242, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.8, Dice: 0.5648 Iou :0.9048, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 1, Dice: 0.5515 Iou :0.8699, Distance: 7.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.05, Dice: 0.0824 Iou :0.1382, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.15, Dice: 0.4317 Iou :0.7507, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.1, Dice: 0.0395 Iou :0.233, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.25, Dice: 0.027 Iou :0.102, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.2, Dice: 0.168 Iou :0.5714, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.4, Dice: 0.3452 Iou :0.3799, Distance: 3.67
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitud: 0.6, Dice: 0.2274 Iou :0.396, Distance: 3.67

# %%
dice_test_medio_total=dice_medio_test/pasos_test
print("Dice_medio_total="+str(dice_test_medio_total))
# Out:
# Dice_medio_total=0.555272911070469

# %%
iou_test_medio_total=iou_medio_test/pasos_test
print("IOU_medio_total="+str(iou_test_medio_total))
# Out:
# IOU_medio_total=0.7312615096150358

# %%
# Filtrar NaNs y calcular la media para resultados_dice
dices_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_dice.values()]
print(dices_medios_por_magnitud)
# Filtrar NaNs y calcular la media para resultados_iou
ious_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_iou.values()]
print(ious_medios_por_magnitud)
# Out:
# [0.5258699035652046, 0.5916995219231101, 0.6059505332860365, 0.6032252313755453, 0.5927658605505712, 0.5839608885813504, 0.5455947633692995, 0.5035511492494138, 0.4428359096701346]
# [0.773129596468554, 0.7974117587708948, 0.8010177988203326, 0.7860213201725855, 0.7607767259096727, 0.7376960359781515, 0.6938774780742825, 0.645933174682622, 0.5873256541751138]

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in dices_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(dices_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('Dice', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_1961066/1722266948.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in ious_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(ious_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('IOU', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_1961066/3865062909.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# %%
matrix_data_dice = {redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
               for redshift, subdict in dice_results_redshift_with_mag_stream_percentage.items()}

labels_redshift = ['0.05','0.1','0.15','0.2','0.25','0.4','0.6','0.8','1']
labels_mag_percentage = ['1%','2%','3%','4%','5%']

# Convertir los datos en un DataFrame de Pandas
matrix_for_df = []
for redshift in labels_redshift:
    row = []
    for i, mag_label in enumerate(labels_mag_percentage, 1):  # 1, 2, 3, 4, 5
        if redshift in matrix_data_dice and i in matrix_data_dice[redshift]:
            row.append(matrix_data_dice[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Crear DataFrame
df = pd.DataFrame(matrix_for_df, index=labels_redshift, columns=labels_mag_percentage)

print(df)
# Crear el heatmap con anotaciones
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'Dice'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("VIS Dice performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.238582  0.515527  0.490203  0.591514  0.655267
# 0.1   0.261326  0.585563  0.635971  0.691030  0.677321
# 0.15  0.283568  0.595019  0.681488  0.701577  0.665538
# 0.2   0.304238  0.591957  0.674324  0.683541  0.674250
# 0.25  0.319497  0.552264  0.639368  0.684782  0.690376
# 0.4   0.317131  0.557508  0.656445  0.650244  0.662486
# 0.6   0.295915  0.528762  0.619665  0.623253  0.588628
# 0.8   0.253926  0.469313  0.576474  0.581693  0.568493
# 1     0.224328  0.409913  0.502701  0.516099  0.502021

# %%
matrix_data_iou = {redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
               for redshift, subdict in iou_results_redshift_with_mag_stream_percentage.items()}

labels_redshift = ['0.05','0.1','0.15','0.2','0.25','0.4','0.6','0.8','1']
labels_mag_percentage = ['1%','2%','3%','4%','5%']

# Convertir los datos en un DataFrame de Pandas
matrix_for_df = []
for redshift in labels_redshift:
    row = []
    for i, mag_label in enumerate(labels_mag_percentage, 1):  # 1, 2, 3, 4, 5
        if redshift in matrix_data_iou and i in matrix_data_iou[redshift]:
            row.append(matrix_data_iou[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Crear DataFrame
df = pd.DataFrame(matrix_for_df, index=labels_redshift, columns=labels_mag_percentage)

print(df)
# Crear el heatmap con anotaciones
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'IoU'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("VIS Intersection over union performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.377137  0.734042  0.841120  0.862311  0.866638
# 0.1   0.489357  0.772937  0.882976  0.879096  0.866996
# 0.15  0.450638  0.802753  0.876380  0.890586  0.871320
# 0.2   0.462947  0.791534  0.853243  0.861546  0.863382
# 0.25  0.454535  0.718877  0.824159  0.842273  0.877257
# 0.4   0.436545  0.660492  0.827129  0.821239  0.863311
# 0.6   0.348922  0.621139  0.790911  0.799664  0.815259
# 0.8   0.289057  0.514828  0.779875  0.791013  0.769872
# 1     0.281341  0.478756  0.691504  0.708065  0.703013

# %%
matrix_data_dice_distance = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in dice_results_redshift_with_distance.items()
}

matrix_for_df_distance = []
for redshift in labels_redshift:
    row = []
    for distance_label in distance_labels:
        if redshift in matrix_data_dice_distance and distance_label in matrix_data_dice_distance[redshift]:
            row.append(matrix_data_dice_distance[redshift][distance_label])
        else:
            row.append(np.nan)
    matrix_for_df_distance.append(row)

df_distance = pd.DataFrame(matrix_for_df_distance, 
                          index=labels_redshift, 
                          columns=distance_labels)

print("\n=== Dice vs Distance to Galaxy Center ===")
print(df_distance)

plt.figure(figsize=(10, 6))
sns.heatmap(df_distance, annot=True, fmt=".3f", cmap="magma", 
           linewidths=0.5, cbar_kws={'label': 'Dice'}, 
           vmin=0, vmax=1.0)
plt.xlabel('Distance to Galaxy Center (pixels)')
plt.ylabel('Redshift')
plt.title("VIS Dice performance vs Distance to Galaxy Center")
plt.tight_layout()
plt.show()
# Out:
# === Dice vs Distance to Galaxy Center ===
#           2-10     10-17     17-25     25-32     32-40
# 0.05  0.419685  0.514780  0.586680  0.531068  0.566051
# 0.1   0.501218  0.586020  0.610449  0.664372  0.619411
# 0.15  0.506020  0.617037  0.624814  0.692180  0.622321
# 0.2   0.485074  0.628395  0.627480  0.678873  0.627433
# 0.25  0.484413  0.609498  0.625510  0.656257  0.609835
# 0.4   0.423605  0.576140  0.639009  0.671765  0.629379
# 0.6   0.402435  0.532180  0.588506  0.632984  0.593420
# 0.8   0.379079  0.464702  0.568069  0.590934  0.519923
# 1     0.352640  0.410834  0.490373  0.522755  0.445935

# %%
matrix_data_iou_distance = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in iou_results_redshift_with_distance.items()
}

matrix_for_df_iou_distance = []
for redshift in labels_redshift:
    row = []
    for distance_label in distance_labels:
        if redshift in matrix_data_iou_distance and distance_label in matrix_data_iou_distance[redshift]:
            row.append(matrix_data_iou_distance[redshift][distance_label])
        else:
            row.append(np.nan)
    matrix_for_df_iou_distance.append(row)

df_iou_distance = pd.DataFrame(matrix_for_df_iou_distance, 
                              index=labels_redshift, 
                              columns=distance_labels)

print("\n=== IoU vs Distance to Galaxy Center ===")
print(df_iou_distance)

plt.figure(figsize=(10, 6))
sns.heatmap(df_iou_distance, annot=True, fmt=".3f", cmap="magma", 
           linewidths=0.5, cbar_kws={'label': 'IoU'}, 
           vmin=0, vmax=1.0)
plt.xlabel('Distance to Galaxy Center (pixels)')
plt.ylabel('Redshift')
plt.title("VIS IoU performance vs Distance to Galaxy Center")
plt.tight_layout()
plt.show()
# Out:
# === IoU vs Distance to Galaxy Center ===
#           2-10     10-17     17-25     25-32     32-40
# 0.05  0.700771  0.762452  0.798929  0.809253  0.801722
# 0.1   0.716498  0.809020  0.801781  0.936900  0.778218
# 0.15  0.738983  0.808701  0.797699  0.931280  0.780941
# 0.2   0.771003  0.780633  0.761342  0.870143  0.784101
# 0.25  0.776681  0.783743  0.735259  0.830068  0.715489
# 0.4   0.720519  0.774369  0.731168  0.783140  0.707084
# 0.6   0.673229  0.730644  0.695904  0.743132  0.653179
# 0.8   0.620677  0.696514  0.647984  0.701980  0.594537
# 1     0.558400  0.587063  0.602086  0.667215  0.546454
