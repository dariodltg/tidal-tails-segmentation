# %%
import copy
import cv2
import glob
import math
import matplotlib.pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import numpy as np
import os
import pandas as pd
import seaborn as sns
from astropy.io import fits
import torch
from torch.utils.data import Dataset
from torchmetrics import Dice
from torchmetrics import Dice, JaccardIndex
import segmentation_models_pytorch as smp
# Out:
# /home2/dario/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
hyperparameters = {
    'notebook_name': 'Evaluation_VIS_1000imgs_v13_log_no_aug.ipynb',
    'experiment_name': 'Evaluation_VIS_1000imgs_v13_log_no_aug_pad',
    'best_trained_model_name': 'VIS_1000imgs_v13_log_pad',
    'device': torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
    'galaxies_path': 'galaxies_test_VIS/galaxy_and_stream_convolved*.fits',
    'masks_path': '../masks_train_VIS/mask_',
    'original_image_width': 600,
    'original_image_height': 600,
    'target_image_width': 608,
    'target_image_height': 608
}

# %%
def pad_to_size(image, target_h, target_w, pad_value=0):
    """Apply padding to reach target size without distortion"""
    h, w = image.shape[:2]
    pad_h = target_h - h
    pad_w = target_w - w
    
    # Symmetric padding
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    
    if len(image.shape) == 2:  # For masks
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right)), 
                     mode='constant', constant_values=pad_value)
    else:  # For RGB images
        return np.pad(image, ((pad_top, pad_bottom), (pad_left, pad_right), (0, 0)), 
                     mode='constant', constant_values=pad_value)

# %%
def get_galaxy_number(galaxy_name: str):
    return os.path.basename(galaxy_name).split('_')[4]

def get_galaxy_magnitude(galaxy_name: str):
    return os.path.basename(galaxy_name).split('_')[5]

def normalize_01(inp: np.ndarray):
    """Squash image input to the value range [0, 1] (no clipping)"""
    inp_out = (inp - np.min(inp)) / np.ptp(inp)
    return inp_out

def logarithmic_image(img: np.ndarray) -> np.ndarray:
    """
    Apply logarithmic scaling to the image to increase contrast
    """
    img_log = np.log(img, where=(img > 0))
    min_value = np.min(img_log)
    np.putmask(img_log, img != 0, img_log + abs(min_value))
    return img_log

# %%
def get_mag_stream_percentage(galaxy_number):
    
    catalogs_folder_path = "../../dataset_generation/catalogs_for_checking" 
    catalog_path = os.path.join(catalogs_folder_path, "stream_characteristics_" + str(galaxy_number) + ".txt")
    df = pd.read_csv(catalog_path, delimiter=r"\s+", engine="python")
    mag_bulge = df.iloc[1, 3]
    mag_disk = df.iloc[1, 8]
    mag_stream = df.iloc[1, 13]
    zeropoint = 30.132  # For VIS, (For NISP is 30)
    flux_bulge = 10 ** ((mag_bulge - zeropoint) / (-2.5)) 
    flux_disk = 10 ** ((mag_disk - zeropoint) / (-2.5))
    flux_galaxy = flux_bulge + flux_disk
    flux_stream = 10 ** ((mag_stream - zeropoint) / (-2.5)) 
    mag_stream_percentage = flux_stream / flux_galaxy
    mag_stream_percentage_rounded_up = math.ceil(mag_stream_percentage * 100)
    if mag_stream_percentage_rounded_up == 6:
        mag_stream_percentage_rounded_up = 5
    # print("MAG_STREAM_PERCENTAGE: " + str(mag_stream_percentage) + "->" + str(mag_stream_percentage_rounded_up) + "%")
    return mag_stream_percentage_rounded_up

# %%
def get_distance_to_galaxy_center(galaxy_number):
    catalogs_folder_path = "../../dataset_generation/catalogs_for_checking" 
    catalog_path = os.path.join(catalogs_folder_path, "stream_characteristics_" + str(galaxy_number) + ".txt")
    df = pd.read_csv(catalog_path, delimiter=r"\s+", engine="python")
    distance_to_galaxy_center = df.iloc[1, 14]
    # print("RR_STREAM: " + str(distance_to_galaxy_center))
    return distance_to_galaxy_center

# %%
class MyDataset(Dataset):
    """
    Basic dataset without any augmentation
    """
    def __init__(self, galaxies_with_tidal_streams, transform=None):
        """
        Dataset constructor
        @param galaxies_with_tidal_streams: List of paths to files containing galaxy data
        """
        self.galaxies_with_tidal_streams = galaxies_with_tidal_streams
        self.transform = transform

    def __getitem__(self, index):
        # Open the galaxy image with tidal stream
        path = self.galaxies_with_tidal_streams[index]
        actual_magnitude = get_galaxy_magnitude(path)
        
        galaxy_fits = fits.open(self.galaxies_with_tidal_streams[index])
        x = galaxy_fits[0].data.astype(np.float32)
        # Open the corresponding mask for the image
        galaxy_number = get_galaxy_number(self.galaxies_with_tidal_streams[index])
        galaxy_magnitude = get_galaxy_magnitude(self.galaxies_with_tidal_streams[index])
        mag_stream_percentage = get_mag_stream_percentage(galaxy_number)
        distance_to_galaxy_center = get_distance_to_galaxy_center(galaxy_number)
        y = np.array(cv2.imread(hyperparameters['masks_path'] + str(galaxy_number) + "_" + str(galaxy_magnitude) + ".png", 0)).astype(np.float32)
        # x = normalize_01(x)
        x_tensor_for_visualization = copy.deepcopy(x)
        x = logarithmic_image(x)

        x = normalize_01(x)

        x = pad_to_size(x, hyperparameters['target_image_height'], hyperparameters['target_image_width'])
        y = pad_to_size(y, hyperparameters['target_image_height'], hyperparameters['target_image_width'])
        if self.transform is not None:
            augmented = self.transform(image=x, mask=y)
            x_tensor = augmented["image"]
            y_tensor = augmented["mask"].long()
        else:
            x_tensor = torch.from_numpy(x).float()
            x_tensor = torch.unsqueeze(x_tensor, dim=0)
            y_tensor = torch.from_numpy(y).long()
        
        # Reshape the tensors
        y_tensor = torch.unsqueeze(y_tensor, dim=0)
        return x_tensor, y_tensor, path, actual_magnitude, x_tensor_for_visualization, mag_stream_percentage, distance_to_galaxy_center
    
    def __len__(self):
        """
        Returns the length of the dataset
        """
        return len(self.galaxies_with_tidal_streams)

# %%
dice = Dice(num_classes=2, average='macro', ignore_index=0)
iou = JaccardIndex(task='multiclass', num_classes=2, average='none', ignore_index=0)
test_images = glob.glob(hyperparameters['galaxies_path'])
test_images.sort()
# Load the test dataset
test_dataset = MyDataset(test_images)
print("Number of valid images: " + str(len(test_images)))
device = hyperparameters['device']
# dice.to(device)
# Out:
# Number of valid images: 1798

# %%
unet = smp.Unet(
    encoder_name="resnet18",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
# Load the previously trained model
model_path = hyperparameters['best_trained_model_name']
best_model = unet
best_model.load_state_dict(torch.load(model_path))
best_model.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# ==========================================
# 1. DATA STRUCTURES DEFINITION
# ==========================================
dice_results = {
    '0.05': [], '0.1': [], '0.15': [], '0.2': [], '0.25': [],
    '0.4': [], '0.6': [], '0.8': [], '1': [],
}
iou_results = {
    '0.05': [], '0.1': [], '0.15': [], '0.2': [], '0.25': [],
    '0.4': [], '0.6': [], '0.8': [], '1': [],
}

dice_results_redshift_with_mag_stream_percentage = {
    '0.05': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.1': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.15': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.2': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.25': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.4': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.6': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.8': {1: [], 2: [], 3: [], 4: [], 5: []},
    '1': {1: [], 2: [], 3: [], 4: [], 5: []},
}

iou_results_redshift_with_mag_stream_percentage = {
    '0.05': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.1': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.15': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.2': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.25': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.4': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.6': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.8': {1: [], 2: [], 3: [], 4: [], 5: []},
    '1': {1: [], 2: [], 3: [], 4: [], 5: []},
}

# NEW STRUCTURES FOR DISTANCE
dice_results_redshift_with_distance = {
    '0.05': {}, '0.1': {}, '0.15': {}, '0.2': {}, '0.25': {},
    '0.4': {}, '0.6': {}, '0.8': {}, '1': {},
}

iou_results_redshift_with_distance = {
    '0.05': {}, '0.1': {}, '0.15': {}, '0.2': {}, '0.25': {},
    '0.4': {}, '0.6': {}, '0.8': {}, '1': {},
}

# ==========================================
# CALCULATE BINS AUTOMATICALLY
# ==========================================
print("Calculating distance range from dataset...")

# Collect all distances from the dataset
all_distances = []
for i in range(len(test_dataset)):
    item = test_dataset.__getitem__(i)
    all_distances.append(item[6])

# Calculate minimum and maximum
min_distance = min(all_distances)
max_distance = max(all_distances)

print(f"Minimum distance: {min_distance:.2f}")
print(f"Maximum distance: {max_distance:.2f}")

# Round to have integer limits
import math
min_distance_rounded = math.floor(min_distance)  # Round down
max_distance_rounded = math.ceil(max_distance)   # Round up

# Create 5 equal intervals
num_bins = 5
bin_width = (max_distance_rounded - min_distance_rounded) / num_bins

# Generate the bins
distance_bins = [min_distance_rounded + i * bin_width for i in range(num_bins + 1)]
# Round each bin to integer
distance_bins = [round(b) for b in distance_bins]

# Create the labels
distance_labels = [f"{distance_bins[i]}-{distance_bins[i+1]}" for i in range(num_bins)]

print(f"\nDistance bins created: {distance_bins}")
print(f"Labels: {distance_labels}")

# ==========================================
# 2. EVALUATION ON TEST DATASET (with visualization)
# ==========================================
width = hyperparameters['target_image_width']
height = hyperparameters['target_image_height']
best_model.eval()
test_steps = 0
mean_dice_test = 0
mean_iou_test = 0
zp = 23.896
pix_scale = 0.1

for i in range(int(len(test_dataset) * 0.01)):
    dataset_item = test_dataset.__getitem__(i)
    item_x = dataset_item[0].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    item_label = dataset_item[1].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    x_tensor_for_visualization = dataset_item[0].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    
    # If the mask is empty, we don't try to segment it
    if np.count_nonzero(item_label) != 0:
        # Get network prediction
        prediction_tensor = best_model(dataset_item[0].reshape((1, 1, width, height)).to(device)).cpu().detach().squeeze()
        # print("original_output:" + str(prediction_tensor))
        # print("shape:" + str(prediction_tensor.shape))
        predicted_mask = torch.argmax(prediction_tensor, dim=0).numpy()
        # print("mask_predicted:" + str(predicted_mask))
        # print("shape:" + str(predicted_mask.shape))
        dice_value = dice(torch.from_numpy(item_label), torch.from_numpy(predicted_mask))
        iou_value = iou(torch.from_numpy(item_label), torch.from_numpy(predicted_mask))[1]
        
        magnitude = dataset_item[3]
        mag_stream_percentage = dataset_item[5]
        distance_to_galaxy_center = dataset_item[6]
        
        print("Path: " + dataset_item[2] + "\nMagnitude: " + magnitude + 
              ", Dice: " + str(round(dice_value.item(), 4)) + " IoU: " + str(round(iou_value.item(), 4)) +
              ", Distance: " + str(round(distance_to_galaxy_center, 2)))
        
        # Store in existing structures
        dice_results[magnitude].append(dice_value.item())
        iou_results[magnitude].append(iou_value.item())
        dice_results_redshift_with_mag_stream_percentage[magnitude][mag_stream_percentage].append(dice_value.item())
        iou_results_redshift_with_mag_stream_percentage[magnitude][mag_stream_percentage].append(iou_value.item())
        
        # NEW: Determine distance bin and store
        distance_bin_idx = None
        for idx in range(len(distance_bins) - 1):
            if distance_bins[idx] <= distance_to_galaxy_center < distance_bins[idx + 1]:
                distance_bin_idx = idx
                break
        
        # Special case: if it's exactly the maximum value
        if distance_to_galaxy_center == distance_bins[-1]:
            distance_bin_idx = len(distance_bins) - 2
        
        if distance_bin_idx is not None:
            distance_label = distance_labels[distance_bin_idx]
            
            # Initialize if it doesn't exist
            if distance_label not in dice_results_redshift_with_distance[magnitude]:
                dice_results_redshift_with_distance[magnitude][distance_label] = []
                iou_results_redshift_with_distance[magnitude][distance_label] = []
            
            # Add results
            dice_results_redshift_with_distance[magnitude][distance_label].append(dice_value.item())
            iou_results_redshift_with_distance[magnitude][distance_label].append(iou_value.item())
        
        mean_dice_test += dice_value.item()
        mean_iou_test += iou_value.item()
        test_steps += 1
        
        # Display image, mask, and predicted mask
        item_x = item_x.astype(np.float32)   
        item_label = item_label.astype(np.uint8)
        predicted_mask = predicted_mask.astype(np.float32)  

        # Remove padding when displaying
        crop = 4
        item_x = item_x[crop:-crop, crop:-crop]
        item_label = item_label[crop:-crop, crop:-crop]
        predicted_mask = predicted_mask[crop:-crop, crop:-crop]

        x_tensor_for_visualization = x_tensor_for_visualization[crop:-crop, crop:-crop]
        zeros = np.zeros((hyperparameters['original_image_width'], hyperparameters['original_image_width']))
        ones = np.ones((hyperparameters['original_image_width'], hyperparameters['original_image_width']))

        cmap = colors.ListedColormap(['rebeccapurple', 'yellow', 'crimson', 'lime'])
        bounds = [0, 1, 2, 3, 4]
        norm = colors.BoundaryNorm(bounds, cmap.N)
        diff = np.zeros((hyperparameters['original_image_width'], hyperparameters['original_image_width']))
        diff[(item_label == zeros) & (predicted_mask == zeros)] = 0
        diff[(item_label == ones) & (predicted_mask == ones)] = 1
        diff[(item_label == zeros) & (predicted_mask == ones)] = 2
        diff[(item_label == ones) & (predicted_mask == zeros)] = 3

        fig, (axs0, axs1, axs2, axs3) = plt.subplots(1, 4, figsize=(15, 15))

        sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))

        # Filter inf and nan to calculate limits
        sb_valid = sb_array[np.isfinite(sb_array)]
        min_sb = np.min(sb_valid)
        max_sb = np.max(sb_valid)

        print("min_sb: " + str(min_sb))
        print("max_sb: " + str(max_sb))
        # Use axs0 instead of plt
        imshow_img = axs0.imshow(sb_array, origin='lower', interpolation="none", cmap="viridis_r", vmin=max_sb, vmax=min_sb)
        cb = fig.colorbar(imshow_img, ax=axs0, fraction=0.046, pad=0.04)
        cb.set_label(r'Surface brightness [mag/arcsec$^{2}$]')

        # Use axs0.transData instead of plt.gca().transData
        scalebar = AnchoredSizeBar(axs0.transData, 10. / pix_scale, "10 arcsec", borderpad=1.0, sep=5, loc="lower right", pad=0.5, color="blue", frameon=True, size_vertical=3)
        axs0.add_artist(scalebar)

        axs1.imshow(item_label, interpolation='none', origin="lower")
        axs2.imshow(predicted_mask, interpolation='none', origin="lower", cmap="plasma")
        axs2.text(0.05, 0.95, "Dice: " + str(round(dice_value.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs2.transAxes)
        axs3.imshow(diff, interpolation='none', origin="lower", cmap=cmap, norm=norm)
        axs3.text(0.05, 0.95, "IoU: " + str(round(iou_value.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs3.transAxes)
        plt.subplots_adjust(wspace=0.7)
        plt.show()
# Out:
# Calculating distance range from dataset...
# Minimum distance: 2.00
# Maximum distance: 39.67
#
# Distance bins created: [2, 10, 17, 25, 32, 40]
# Labels: ['2-10', '10-17', '17-25', '25-32', '32-40']
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6704 IoU: 0.5335, Distance: 24.0
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# min_sb: 18.896
# max_sb: 20.71348
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8146 IoU: 0.8606, Distance: 24.0
# min_sb: 18.896
# max_sb: 116.50258
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7595 IoU: 0.7145, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.780426
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.5202 IoU: 0.7357, Distance: 24.0
# min_sb: 18.896
# max_sb: 21.271488
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7879 IoU: 0.8587, Distance: 24.0
# min_sb: 18.896
# max_sb: 21.269924
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.7126 IoU: 0.7088, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.848093
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.5657 IoU: 0.5351, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.914015
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.6089 IoU: 0.6426, Distance: 24.0
# min_sb: 18.896
# max_sb: 21.018547
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.5687 IoU: 0.5556, Distance: 24.0
# min_sb: 18.896
# max_sb: 20.540462
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.738 IoU: 0.5903, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.869875
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7818 IoU: 0.6985, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.51491
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8344 IoU: 0.739, Distance: 12.0
# min_sb: 18.896
# max_sb: 21.017044
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.7826 IoU: 0.7255, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.504658
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7987 IoU: 0.6925, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.921207
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.7532 IoU: 0.8547, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.794588
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.1255 IoU: 0.7333, Distance: 12.0
# min_sb: 18.896
# max_sb: 20.78716
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0084 IoU: 0.0241, Distance: 12.0
# min_sb: 18.896
# max_sb: 21.252823
# /tmp/ipykernel_3291216/4099571475.py:183: RuntimeWarning: divide by zero encountered in log10
#   sb_array = -2.5 * np.log10(x_tensor_for_visualization) + zp + (5 * np.log10(pix_scale))

# %%
# ==========================================
# 1. DATA STRUCTURES DEFINITION
# ==========================================
dice_results = {
    '0.05': [], '0.1': [], '0.15': [], '0.2': [], '0.25': [],
    '0.4': [], '0.6': [], '0.8': [], '1': [],
}
iou_results = {
    '0.05': [], '0.1': [], '0.15': [], '0.2': [], '0.25': [],
    '0.4': [], '0.6': [], '0.8': [], '1': [],
}

dice_results_redshift_with_mag_stream_percentage = {
    '0.05': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.1': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.15': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.2': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.25': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.4': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.6': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.8': {1: [], 2: [], 3: [], 4: [], 5: []},
    '1': {1: [], 2: [], 3: [], 4: [], 5: []},
}

iou_results_redshift_with_mag_stream_percentage = {
    '0.05': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.1': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.15': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.2': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.25': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.4': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.6': {1: [], 2: [], 3: [], 4: [], 5: []},
    '0.8': {1: [], 2: [], 3: [], 4: [], 5: []},
    '1': {1: [], 2: [], 3: [], 4: [], 5: []},
}

# NEW STRUCTURES FOR DISTANCE
dice_results_redshift_with_distance = {
    '0.05': {}, '0.1': {}, '0.15': {}, '0.2': {}, '0.25': {},
    '0.4': {}, '0.6': {}, '0.8': {}, '1': {},
}

iou_results_redshift_with_distance = {
    '0.05': {}, '0.1': {}, '0.15': {}, '0.2': {}, '0.25': {},
    '0.4': {}, '0.6': {}, '0.8': {}, '1': {},
}

# ==========================================
# OUTPUT FOLDER FOR FITS FILES
# ==========================================
filter_name = "VIS"  # Change to NISP_H, NISP_J, or NISP_Y for other filters
output_fits_folder = f"predictions_{filter_name}"
os.makedirs(output_fits_folder, exist_ok=True)
print(f"Output FITS folder created: {output_fits_folder}")

# ==========================================
# CALCULATE BINS AUTOMATICALLY
# ==========================================
print("Calculating distance range from dataset...")

# Collect all distances from the dataset
all_distances = []
for i in range(len(test_dataset)):
    item = test_dataset.__getitem__(i)
    all_distances.append(item[6])

# Calculate minimum and maximum
min_distance = min(all_distances)
max_distance = max(all_distances)

print(f"Minimum distance: {min_distance:.2f}")
print(f"Maximum distance: {max_distance:.2f}")

# Round to have integer limits
import math
min_distance_rounded = math.floor(min_distance)  # Round down
max_distance_rounded = math.ceil(max_distance)   # Round up

# Create 5 equal intervals
num_bins = 5
bin_width = (max_distance_rounded - min_distance_rounded) / num_bins

# Generate the bins
distance_bins = [min_distance_rounded + i * bin_width for i in range(num_bins + 1)]
# Round each bin to integer
distance_bins = [round(b) for b in distance_bins]

# Create the labels
distance_labels = [f"{distance_bins[i]}-{distance_bins[i+1]}" for i in range(num_bins)]

print(f"\nDistance bins created: {distance_bins}")
print(f"Labels: {distance_labels}")

# ==========================================
# 2. EVALUATION ON TEST DATASET
# ==========================================
width = hyperparameters['target_image_width']
height = hyperparameters['target_image_height']
best_model.eval()
test_steps = 0
mean_dice_test = 0
mean_iou_test = 0
zp = 29.9
pix_scale = 0.1

for i in range(int(len(test_dataset))):
    dataset_item = test_dataset.__getitem__(i)
    item_x = dataset_item[0].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    item_label = dataset_item[1].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    x_tensor_for_visualization = dataset_item[0].reshape((1, 1, width, height)).cpu().detach().squeeze().numpy()
    
    # Get the original FITS file path
    original_fits_path = dataset_item[2]
    
    # If the mask is empty, we don't try to segment it
    if np.count_nonzero(item_label) != 0:
        # Get network prediction
        prediction_tensor = best_model(dataset_item[0].reshape((1, 1, width, height)).to(device)).cpu().detach().squeeze()   
        predicted_mask = torch.argmax(prediction_tensor, dim=0).numpy()
        dice_value = dice(torch.from_numpy(item_label), torch.from_numpy(predicted_mask))
        iou_value = iou(torch.from_numpy(item_label), torch.from_numpy(predicted_mask))[1]
        
        magnitude = dataset_item[3]
        mag_stream_percentage = dataset_item[5]
        distance_to_galaxy_center = dataset_item[6]
        
        print("Path: " + dataset_item[2] + "\nMagnitude: " + magnitude + 
              ", Dice: " + str(round(dice_value.item(), 4)) + " IoU: " + str(round(iou_value.item(), 4)) +
              ", Distance: " + str(round(distance_to_galaxy_center, 2)))
        
        # ==========================================
        # SAVE FITS FILE WITH 4 CHANNELS
        # ==========================================
        # Open original FITS to get header
        with fits.open(original_fits_path) as original_hdu:
            original_header = original_hdu[0].header.copy()
        
        # Extract the two channels from prediction_tensor
        channel_1 = prediction_tensor[0].numpy()  # First channel (background logits)
        channel_2 = prediction_tensor[1].numpy()  # Second channel (stream logits)
        
        # Create binary predicted mask (already computed above)
        binary_mask = predicted_mask.astype(np.float32)
        
        # Compute difference between channel 1 and channel 2
        channel_diff = channel_1 - channel_2
        
        # Stack all 4 channels into a 3D array (4, height, width)
        multi_channel_data = np.stack([channel_1, channel_2, binary_mask, channel_diff], axis=0)
        
        # Update header with additional info about the channels
        original_header['NAXIS'] = 3
        original_header['NAXIS3'] = 4
        original_header['CHAN1'] = ('BKG_LOGIT', 'Background class logits')
        original_header['CHAN2'] = ('STR_LOGIT', 'Stream class logits')
        original_header['CHAN3'] = ('BIN_MASK', 'Binary predicted mask')
        original_header['CHAN4'] = ('LOGIT_DIF', 'Difference channel1 - channel2')
        original_header['FILTER'] = (filter_name, 'Euclid filter used')
        original_header['DICE'] = (round(dice_value.item(), 4), 'Dice score')
        original_header['IOU'] = (round(iou_value.item(), 4), 'IoU score')
        
        # Generate output filename
        original_basename = os.path.basename(original_fits_path)
        output_filename = original_basename.replace('.fits', f'_prediction.fits')
        output_path = os.path.join(output_fits_folder, output_filename)
        
        # Create and save the FITS file
        hdu = fits.PrimaryHDU(data=multi_channel_data, header=original_header)
        hdu.writeto(output_path, overwrite=True)
        
        print(f"  -> Saved prediction FITS: {output_path}")
        
        # Store in existing structures
        dice_results[magnitude].append(dice_value.item())
        iou_results[magnitude].append(iou_value.item())
        dice_results_redshift_with_mag_stream_percentage[magnitude][mag_stream_percentage].append(dice_value.item())
        iou_results_redshift_with_mag_stream_percentage[magnitude][mag_stream_percentage].append(iou_value.item())
        
        # NEW: Determine distance bin and store
        distance_bin_idx = None
        for idx in range(len(distance_bins) - 1):
            if distance_bins[idx] <= distance_to_galaxy_center < distance_bins[idx + 1]:
                distance_bin_idx = idx
                break
        
        # Special case: if it's exactly the maximum value
        if distance_to_galaxy_center == distance_bins[-1]:
            distance_bin_idx = len(distance_bins) - 2
        
        if distance_bin_idx is not None:
            distance_label = distance_labels[distance_bin_idx]
            
            # Initialize if it doesn't exist
            if distance_label not in dice_results_redshift_with_distance[magnitude]:
                dice_results_redshift_with_distance[magnitude][distance_label] = []
                iou_results_redshift_with_distance[magnitude][distance_label] = []
            
            # Add results
            dice_results_redshift_with_distance[magnitude][distance_label].append(dice_value.item())
            iou_results_redshift_with_distance[magnitude][distance_label].append(iou_value.item())
        
        mean_dice_test += dice_value.item()
        mean_iou_test += iou_value.item()
        test_steps += 1

print(f"\n{'='*50}")
print(f"Evaluation complete. {test_steps} FITS files saved to '{output_fits_folder}/'")
print(f"{'='*50}")
# Out:
# Output FITS folder created: predictions_VIS
# Calculating distance range from dataset...
# Minimum distance: 2.00
# Maximum distance: 39.67
#
# Distance bins created: [2, 10, 17, 25, 32, 40]
# Labels: ['2-10', '10-17', '17-25', '25-32', '32-40']
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6704 IoU: 0.5335, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8146 IoU: 0.8606, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7595 IoU: 0.7145, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.5202 IoU: 0.7357, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7879 IoU: 0.8587, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.7126 IoU: 0.7088, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.5657 IoU: 0.5351, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.6089 IoU: 0.6426, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.5687 IoU: 0.5556, Distance: 24.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.738 IoU: 0.5903, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7818 IoU: 0.6985, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8344 IoU: 0.739, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.7826 IoU: 0.7255, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7987 IoU: 0.6925, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.7532 IoU: 0.8547, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.1255 IoU: 0.7333, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0084 IoU: 0.0241, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_100_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 12.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_100_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.2457 IoU: 0.9944, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.0 IoU: 0.0, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.3085 IoU: 0.7102, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.2557 IoU: 0.9313, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.2794 IoU: 0.4865, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.3875 IoU: 0.5321, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0367 IoU: 0.0938, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_101_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0391 IoU: 0.1064, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_101_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.2265 IoU: 0.3033, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.2981 IoU: 0.2503, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.2727 IoU: 0.2541, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.454 IoU: 0.3495, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.2592 IoU: 0.2183, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.0029 IoU: 0.0025, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.2187 IoU: 0.1511, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0 IoU: 0.0, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_102_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 39.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_102_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.8049 IoU: 0.7911, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7123 IoU: 0.9379, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7584 IoU: 0.9144, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.8847 IoU: 0.9637, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.888 IoU: 0.9721, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.8959 IoU: 0.9494, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.838 IoU: 0.8688, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.7987 IoU: 0.7568, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_103_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.7973 IoU: 0.7682, Distance: 24.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_103_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.8282 IoU: 0.9531, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7368 IoU: 0.6359, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8532 IoU: 0.7464, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.6265 IoU: 0.5025, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.6663 IoU: 0.4995, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.6232 IoU: 0.5471, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.4343 IoU: 0.4048, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.4959 IoU: 0.4187, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_104_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.1689 IoU: 0.1799, Distance: 22.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_104_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.777 IoU: 0.8867, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.5427 IoU: 0.8824, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.5341 IoU: 0.8459, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.5921 IoU: 0.9479, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.637 IoU: 0.9024, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.0461 IoU: 0.5238, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.7874 IoU: 0.9115, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.5521 IoU: 0.8548, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_105_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.6632 IoU: 0.8514, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_105_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.7464 IoU: 0.9961, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8859 IoU: 0.9737, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7833 IoU: 0.9984, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.9099 IoU: 0.8772, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.9189 IoU: 0.9761, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.9005 IoU: 0.8387, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.7167 IoU: 0.7914, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.6552 IoU: 0.7854, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_106_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.5396 IoU: 0.7415, Distance: 18.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_106_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.1698 IoU: 0.9081, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7168 IoU: 0.9321, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7895 IoU: 0.9759, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.4408 IoU: 1.0, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.6639 IoU: 0.9727, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.4656 IoU: 0.9947, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.4218 IoU: 1.0, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.3583 IoU: 1.0, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_107_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.4646 IoU: 0.9388, Distance: 4.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_107_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.783 IoU: 0.9968, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8907 IoU: 0.9579, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8601 IoU: 0.9911, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.8566 IoU: 0.8278, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.8642 IoU: 0.8518, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.9194 IoU: 0.8696, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.8935 IoU: 0.8136, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.8439 IoU: 0.7796, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_108_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.7269 IoU: 0.6667, Distance: 26.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_108_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.1779 IoU: 0.9163, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7232 IoU: 0.9787, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.6727 IoU: 0.9721, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.792 IoU: 0.9947, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7742 IoU: 0.9837, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.8002 IoU: 1.0, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.8046 IoU: 1.0, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.8577 IoU: 1.0, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_109_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.7665 IoU: 1.0, Distance: 13.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_109_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.7109 IoU: 0.888, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7196 IoU: 0.7337, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8127 IoU: 0.7921, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.7735 IoU: 0.7722, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7073 IoU: 0.7197, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.8167 IoU: 0.7779, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.9162 IoU: 0.9153, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.9398 IoU: 0.9349, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_10_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.9243 IoU: 0.9043, Distance: 11.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_10_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6939 IoU: 0.7801, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.5336 IoU: 1.0, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.6452 IoU: 0.9477, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.5845 IoU: 0.9049, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.501 IoU: 0.9745, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.5936 IoU: 0.9116, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.6188 IoU: 0.9409, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.7621 IoU: 0.9229, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_110_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.8138 IoU: 0.9025, Distance: 13.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_110_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.0 IoU: 0.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.0 IoU: 0.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.0 IoU: 0.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.0021 IoU: 1.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.266 IoU: 0.961, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.304 IoU: 0.7217, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0 IoU: 0.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_111_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_111_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.3119 IoU: 0.9903, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7384 IoU: 0.9897, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7635 IoU: 0.9981, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.7123 IoU: 0.9083, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7348 IoU: 0.9182, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.7732 IoU: 0.8503, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.8338 IoU: 0.9251, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.7481 IoU: 0.9573, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_112_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.7124 IoU: 0.9045, Distance: 33.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_112_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.1745 IoU: 0.7597, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8191 IoU: 0.9446, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7316 IoU: 0.9695, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.8727 IoU: 0.7908, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.8908 IoU: 0.8631, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.8201 IoU: 0.695, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.7474 IoU: 0.5967, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.6783 IoU: 0.5132, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_113_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.657 IoU: 0.4897, Distance: 19.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_113_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.5746 IoU: 0.6612, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.5992 IoU: 0.5375, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.6584 IoU: 0.6021, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.5077 IoU: 0.4533, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.6723 IoU: 0.5399, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.5559 IoU: 0.4854, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.6904 IoU: 0.5741, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.5514 IoU: 0.4625, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_114_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.6016 IoU: 0.4611, Distance: 37.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_114_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.2447 IoU: 0.8363, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.7696 IoU: 0.9383, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7345 IoU: 0.9219, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.6231 IoU: 0.9645, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.6237 IoU: 0.9572, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.4486 IoU: 1.0, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.3942 IoU: 1.0, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.4473 IoU: 1.0, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_115_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.3824 IoU: 0.7324, Distance: 6.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_115_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.0059 IoU: 0.0162, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.2627 IoU: 0.349, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.0334 IoU: 0.0783, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.3882 IoU: 0.3682, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.2434 IoU: 0.2805, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.2615 IoU: 0.2256, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.0 IoU: 0.0, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0 IoU: 0.0, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_116_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 10.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_116_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6381 IoU: 0.642, Distance: 4.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_117_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.4495 IoU: 0.4056, Distance: 4.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_117_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.519 IoU: 0.4511, Distance: 4.0
# ...
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.8685 IoU: 0.9206, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_274_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.8619 IoU: 0.7848, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_274_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.9144 IoU: 0.8752, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_274_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.886 IoU: 0.8097, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_274_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_274_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.8252 IoU: 0.7248, Distance: 36.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_274_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6549 IoU: 0.9961, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.1488 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.4909 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.0108 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.1413 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.1545 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.1922 IoU: 0.9143, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0784 IoU: 0.8333, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_275_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_275_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.0521 IoU: 0.6335, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.1849 IoU: 0.7233, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.0042 IoU: 0.093, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.3959 IoU: 0.7949, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.2465 IoU: 0.7037, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.5061 IoU: 0.8993, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.0081 IoU: 1.0, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.0 IoU: 0.0, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_276_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 6.0
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_276_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.6977 IoU: 0.973, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.8721 IoU: 0.9662, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.8628 IoU: 0.9598, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.8332 IoU: 0.8741, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.9103 IoU: 0.9202, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.886 IoU: 0.9287, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.9418 IoU: 0.9346, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.9099 IoU: 0.9196, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_277_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.8999 IoU: 0.8275, Distance: 38.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_277_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.7778 IoU: 0.836, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.6141 IoU: 1.0, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.7389 IoU: 0.9956, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.8661 IoU: 0.9764, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.7763 IoU: 0.9944, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.858 IoU: 0.9342, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.7155 IoU: 0.7155, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.1014 IoU: 1.0, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_278_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.0 IoU: 0.0, Distance: 12.33
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_278_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.0024 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.6855 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.6265 IoU: 0.9835, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.4951 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.6112 IoU: 1.0, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.5759 IoU: 0.9778, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.6425 IoU: 0.9242, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.8, Dice: 0.5648 IoU: 0.9048, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_0.8_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_279_1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 1, Dice: 0.5515 IoU: 0.8699, Distance: 7.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_279_1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.05, Dice: 0.0824 IoU: 0.1382, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.05_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.15, Dice: 0.4317 IoU: 0.7507, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.15_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.1, Dice: 0.0395 IoU: 0.233, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.1_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.25, Dice: 0.027 IoU: 0.102, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.25_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.2, Dice: 0.168 IoU: 0.5714, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.2_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.4, Dice: 0.3452 IoU: 0.3799, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.4_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
# Path: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706.fits
# Magnitude: 0.6, Dice: 0.2274 IoU: 0.396, Distance: 3.67
#   -> Saved prediction FITS: predictions_VIS/galaxy_and_stream_convolved_27_0.6_VIS_in_EUC_VIS_LSB_ObsID_2706_prediction.fits
#
# ==================================================
# Evaluation complete. 1785 FITS files saved to 'predictions_VIS/'
# ==================================================

# %%
total_mean_dice_test = mean_dice_test / test_steps
print("Total_mean_Dice=" + str(total_mean_dice_test))
# Out:
# Total_mean_Dice=0.5552758109282653

# %%
total_mean_iou_test = mean_iou_test / test_steps
print("Total_mean_IoU=" + str(total_mean_iou_test))
# Out:
# Total_mean_IoU=0.7312614398258438

# %%
# Filter NaNs and calculate mean for dice_results
mean_dice_by_magnitude = [np.mean([x for x in lst if not np.isnan(x)]) for lst in dice_results.values()]
print(mean_dice_by_magnitude)
# Filter NaNs and calculate mean for iou_results
mean_iou_by_magnitude = [np.mean([x for x in lst if not np.isnan(x)]) for lst in iou_results.values()]
print(mean_iou_by_magnitude)
# Out:
# [0.5258699035652046, 0.5916995219231101, 0.6059505332860365, 0.6032511126063764, 0.5927658605505712, 0.5839608885813504, 0.5455947633692995, 0.5035511492494138, 0.4428359096701346]
# [0.773129596468554, 0.7974117587708948, 0.8010177988203326, 0.7860206973040477, 0.7607767259096727, 0.7376960359781515, 0.6938774780742825, 0.645933174682622, 0.5873256541751138]

# %%
# Create a color palette based on the achieved values, normalized between 0 and 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Adjust the figure size
plt.figure(figsize=(12, 8))

# Create the bar chart
bar_colors = [sm.to_rgba(value) for value in mean_dice_by_magnitude]
ax = sns.barplot(x=list(dice_results.keys()), y=mean_dice_by_magnitude, palette=bar_colors)

# Adjust y-axis limits between 0 and 1
ax.set_ylim(0, 1)

# Add labels with values above the bars
for i, value in enumerate(mean_dice_by_magnitude):
    ax.text(i, value + 0.01, f'{value:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Add title and adjust labels
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('Dice', fontsize=16)

# Adjust axis label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Add grid lines
ax.grid(True, linestyle='--', linewidth=0.5)

# Add colorbar
cbar = plt.colorbar(sm, ax=ax)

# Improve overall design
sns.despine()
# plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_3291216/3350598550.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(dice_results.keys()), y=mean_dice_by_magnitude, palette=bar_colors)

# %%
# Create a color palette based on the achieved values, normalized between 0 and 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Adjust the figure size
plt.figure(figsize=(12, 8))

# Create the bar chart
bar_colors = [sm.to_rgba(value) for value in mean_iou_by_magnitude]
ax = sns.barplot(x=list(dice_results.keys()), y=mean_iou_by_magnitude, palette=bar_colors)

# Adjust y-axis limits between 0 and 1
ax.set_ylim(0, 1)

# Add labels with values above the bars
for i, value in enumerate(mean_iou_by_magnitude):
    ax.text(i, value + 0.01, f'{value:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Add title and adjust labels
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('IoU', fontsize=16)

# Adjust axis label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Add grid lines
ax.grid(True, linestyle='--', linewidth=0.5)

# Add colorbar
cbar = plt.colorbar(sm, ax=ax)

# Improve overall design
sns.despine()
# plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_3291216/1531242130.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(dice_results.keys()), y=mean_iou_by_magnitude, palette=bar_colors)

# %%
dice_matrix_data = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in dice_results_redshift_with_mag_stream_percentage.items()
}

redshift_labels = ['0.05', '0.1', '0.15', '0.2', '0.25', '0.4', '0.6', '0.8', '1']
mag_percentage_labels = ['1%', '2%', '3%', '4%', '5%']

# Convert data to a Pandas DataFrame
matrix_for_df = []
for redshift in redshift_labels:
    row = []
    for i, mag_label in enumerate(mag_percentage_labels, 1):  # 1, 2, 3, 4, 5
        if redshift in dice_matrix_data and i in dice_matrix_data[redshift]:
            row.append(dice_matrix_data[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Create DataFrame
df = pd.DataFrame(matrix_for_df, index=redshift_labels, columns=mag_percentage_labels)

print(df)
# Create heatmap with annotations
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'Dice'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("VIS Dice performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.238582  0.515527  0.490203  0.591514  0.655267
# 0.1   0.261326  0.585563  0.635971  0.691030  0.677321
# 0.15  0.283568  0.595019  0.681488  0.701577  0.665538
# 0.2   0.304238  0.591957  0.674453  0.683541  0.674250
# 0.25  0.319497  0.552264  0.639368  0.684782  0.690376
# 0.4   0.317131  0.557508  0.656445  0.650244  0.662486
# 0.6   0.295915  0.528762  0.619665  0.623253  0.588628
# 0.8   0.253926  0.469313  0.576474  0.581693  0.568493
# 1     0.224328  0.409913  0.502701  0.516099  0.502021

# %%
iou_matrix_data = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in iou_results_redshift_with_mag_stream_percentage.items()
}

redshift_labels = ['0.05', '0.1', '0.15', '0.2', '0.25', '0.4', '0.6', '0.8', '1']
mag_percentage_labels = ['1%', '2%', '3%', '4%', '5%']

# Convert data to a Pandas DataFrame
matrix_for_df = []
for redshift in redshift_labels:
    row = []
    for i, mag_label in enumerate(mag_percentage_labels, 1):  # 1, 2, 3, 4, 5
        if redshift in iou_matrix_data and i in iou_matrix_data[redshift]:
            row.append(iou_matrix_data[redshift][i])
        else:
            row.append(np.nan)
    matrix_for_df.append(row)

# Create DataFrame
df = pd.DataFrame(matrix_for_df, index=redshift_labels, columns=mag_percentage_labels)

print(df)
# Create heatmap with annotations
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, fmt=".3f", cmap="magma", linewidths=0.5,
           cbar_kws={'label': 'IoU'}, vmin=0, vmax=1.0)

plt.xlabel('Stream magnitude over galaxy magnitude percentage')
plt.ylabel('Redshift')
plt.title("VIS Intersection over Union performance")
plt.tight_layout()
plt.show()
# Out:
#             1%        2%        3%        4%        5%
# 0.05  0.377137  0.734042  0.841120  0.862311  0.866638
# 0.1   0.489357  0.772937  0.882976  0.879096  0.866996
# 0.15  0.450638  0.802753  0.876380  0.890586  0.871320
# 0.2   0.462947  0.791534  0.853240  0.861546  0.863382
# 0.25  0.454535  0.718877  0.824159  0.842273  0.877257
# 0.4   0.436545  0.660492  0.827129  0.821239  0.863311
# 0.6   0.348922  0.621139  0.790911  0.799664  0.815259
# 0.8   0.289057  0.514828  0.779875  0.791013  0.769872
# 1     0.281341  0.478756  0.691504  0.708065  0.703013

# %%
dice_distance_matrix_data = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in dice_results_redshift_with_distance.items()
}

distance_matrix_for_df = []
for redshift in redshift_labels:
    row = []
    for distance_label in distance_labels:
        if redshift in dice_distance_matrix_data and distance_label in dice_distance_matrix_data[redshift]:
            row.append(dice_distance_matrix_data[redshift][distance_label])
        else:
            row.append(np.nan)
    distance_matrix_for_df.append(row)

df_distance = pd.DataFrame(distance_matrix_for_df, 
                          index=redshift_labels, 
                          columns=distance_labels)

print("\n=== Dice vs Distance to Galaxy Center ===")
print(df_distance)

plt.figure(figsize=(10, 6))
sns.heatmap(df_distance, annot=True, fmt=".3f", cmap="magma", 
           linewidths=0.5, cbar_kws={'label': 'Dice'}, 
           vmin=0, vmax=1.0)
plt.xlabel('Distance to Galaxy Center (pixels)')
plt.ylabel('Redshift')
plt.title("VIS Dice performance vs Distance to Galaxy Center")
plt.tight_layout()
plt.show()
# Out:
# === Dice vs Distance to Galaxy Center ===
#           2-10     10-17     17-25     25-32     32-40
# 0.05  0.419685  0.514780  0.586680  0.531068  0.566051
# 0.1   0.501218  0.586020  0.610449  0.664372  0.619411
# 0.15  0.506020  0.617037  0.624814  0.692180  0.622321
# 0.2   0.485191  0.628395  0.627480  0.678873  0.627433
# 0.25  0.484413  0.609498  0.625510  0.656257  0.609835
# 0.4   0.423605  0.576140  0.639009  0.671765  0.629379
# 0.6   0.402435  0.532180  0.588506  0.632984  0.593420
# 0.8   0.379079  0.464702  0.568069  0.590934  0.519923
# 1     0.352640  0.410834  0.490373  0.522755  0.445935

# %%
iou_distance_matrix_data = {
    redshift: {key: np.nanmean(values) for key, values in subdict.items()} 
    for redshift, subdict in iou_results_redshift_with_distance.items()
}

iou_distance_matrix_for_df = []
for redshift in redshift_labels:
    row = []
    for distance_label in distance_labels:
        if redshift in iou_distance_matrix_data and distance_label in iou_distance_matrix_data[redshift]:
            row.append(iou_distance_matrix_data[redshift][distance_label])
        else:
            row.append(np.nan)
    iou_distance_matrix_for_df.append(row)

df_iou_distance = pd.DataFrame(iou_distance_matrix_for_df, 
                              index=redshift_labels, 
                              columns=distance_labels)

print("\n=== IoU vs Distance to Galaxy Center ===")
print(df_iou_distance)

plt.figure(figsize=(10, 6))
sns.heatmap(df_iou_distance, annot=True, fmt=".3f", cmap="magma", 
           linewidths=0.5, cbar_kws={'label': 'IoU'}, 
           vmin=0, vmax=1.0)
plt.xlabel('Distance to Galaxy Center (pixels)')
plt.ylabel('Redshift')
plt.title("VIS IoU performance vs Distance to Galaxy Center")
plt.tight_layout()
plt.show()
# Out:
# === IoU vs Distance to Galaxy Center ===
#           2-10     10-17     17-25     25-32     32-40
# 0.05  0.700771  0.762452  0.798929  0.809253  0.801722
# 0.1   0.716498  0.809020  0.801781  0.936900  0.778218
# 0.15  0.738983  0.808701  0.797699  0.931280  0.780941
# 0.2   0.771000  0.780633  0.761342  0.870143  0.784101
# 0.25  0.776681  0.783743  0.735259  0.830068  0.715489
# 0.4   0.720519  0.774369  0.731168  0.783140  0.707084
# 0.6   0.673229  0.730644  0.695904  0.743132  0.653179
# 0.8   0.620677  0.696514  0.647984  0.701980  0.594537
# 1     0.558400  0.587063  0.602086  0.667215  0.546454
