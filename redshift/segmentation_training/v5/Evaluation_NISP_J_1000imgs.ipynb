# %%
import copy
import cv2
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import os
import seaborn as sns
from astropy.io import fits
import torch
from torch.utils.data import Dataset
from torchmetrics import Dice
from torchmetrics import Dice, JaccardIndex
import segmentation_models_pytorch as smp

# %%
hiperparametros = {'nombre_notebook': 'Evaluation_NISP_J_1000_v5imgs.ipynb',
                    'nombre_experimento' : 'Evaluation_NISP_J_1000_v5imgs',
                    'nombre_mejor_modelo_entrenado' : 'NISP_J_1000imgs_v5',
                    'device' : torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
                    'ruta_galaxias' : 'galaxies_test_NISP_J/galaxy_and_stream_convolved*.fits',
                    'ruta_mascaras' : '../masks_train_NISP_J/mask_',
                    'ancho_imagen_original' : 200,
                    'alto_imagen_original' : 200,
                    'ancho_imagen_deseado' : 224,
                    'alto_imagen_deseado' : 224}

# %%
def get_galaxy_number(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[4]

def get_galaxy_magnitude(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[5]

def normalize_01(inp: np.ndarray):
    """Squash image input to the value range [0, 1] (no clipping)"""
    inp_out = (inp - np.min(inp)) / np.ptp(inp)
    return inp_out

def imagen_logaritmica(img: np.ndarray)->np.ndarray:
    """
    Escalamos de forma logarítmica la imagen para aumentar el contraste
    """
    img_log = np.log(img, where=(img>0))
    valor_minimo = np.min(img_log)
    np.putmask(img_log, img!=0, img_log+abs(valor_minimo))
    return img_log

# %%
class MyDataset(Dataset):
    """
    Dataset básico sin ningún tipo de augmentation
    """
    def __init__(self, galaxias_con_colas_de_marea, transform=None):
        """
        Constructor del dataset
        @param galaxias_con_colas_de_marea: Lista de rutas a los ficheros que contienen los datos de las galaxias
        """
        self.galaxias_con_colas_de_marea = galaxias_con_colas_de_marea
        self.transform=transform

    def __getitem__(self, index):
        #Abrimos la imagen de la galaxia con cola de marea
        ruta = self.galaxias_con_colas_de_marea[index]
        magnitud_real = get_galaxy_magnitude(ruta)
        galaxy_fits = fits.open(self.galaxias_con_colas_de_marea[index])
        x = galaxy_fits[0].data.astype(np.float32)
        #Abrimos la mascara correspondiente a la imagen
        numero_galaxia = get_galaxy_number(self.galaxias_con_colas_de_marea[index])
        magnitud_galaxia = get_galaxy_magnitude(self.galaxias_con_colas_de_marea[index])
        
        y = np.array(cv2.imread(hiperparametros['ruta_mascaras']+str(numero_galaxia)+"_"+str(magnitud_galaxia)+".png",0)).astype(np.float32)
        #x = normalize_01(x)
        x_tensor_visualizar = copy.deepcopy(x)
        x = imagen_logaritmica(x)

        x = normalize_01(x)
        # Assuming 'input_item' is your input image
        x = cv2.resize(x, (hiperparametros['ancho_imagen_deseado'], hiperparametros['alto_imagen_deseado']))
        y = cv2.resize(y, (hiperparametros['ancho_imagen_deseado'], hiperparametros['alto_imagen_deseado']))
        if(self.transform is not None):
            augmented = self.transform(image=x, mask=y)
            x_tensor= augmented["image"]
            y_tensor= augmented["mask"].long()
        else:
            x_tensor = torch.from_numpy(x).float()
            x_tensor=torch.unsqueeze(x_tensor, dim=0)
            y_tensor = torch.from_numpy(y).long()
        
        #Hacemos reshape de los tensores
        y_tensor=torch.unsqueeze(y_tensor, dim=0)
        return x_tensor, y_tensor, ruta, magnitud_real, x_tensor_visualizar
    
    def __len__(self):
        """
        Devuelve la longitud del dataset
        """
        return len(self.galaxias_con_colas_de_marea)

# %%
dice = Dice(num_classes=2, average='macro', ignore_index=0)
iou = JaccardIndex(task='multiclass', num_classes=2, average='macro', ignore_index=0)
imagenes_test = glob.glob(hiperparametros['ruta_galaxias'])
imagenes_test.sort()
#Cargamos el dataset de test
test_dataset= MyDataset(imagenes_test)
print("Number of valid images: " + str(len(imagenes_test)))
device = hiperparametros['device']
#dice.to(device)
# Out:
# Number of valid images: 1749

# %%
unet = smp.Unet(
    encoder_name="resnet18",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
#Cargamos el modelo previamente entrenado
ruta_modelo = hiperparametros['nombre_mejor_modelo_entrenado']
mejor_modelo = unet
mejor_modelo.load_state_dict(torch.load(ruta_modelo))
mejor_modelo.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
resultados_dice = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
resultados_iou = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
# With photos
ancho = hiperparametros['ancho_imagen_deseado']
alto =hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test=0
dice_medio_test=0
iou_medio_test = 0
zp = 30 # TODO Preguntar a Fer
pix_scale = 0.3 # TODO Preguntar a Fer
for i in range(int(len(test_dataset) * 0.01)):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    x_tensor_visualizar = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    #Si la máscara es vacía no intentamos segmentarla, para que no cuente en el dice
    if(np.count_nonzero(item_label)!=0):
        #Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        magnitud = item_dataset[3]
        print("Ruta: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + ", Dice: "+str(round(valor_dice.item(), 4))+", IOU: "+str(round(valor_iou.item(), 4))+" :")
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        #Mostramos imagen, mascara y mascara predicha
        item_x = cv2.resize(item_x.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)
        
        item_label = cv2.resize(item_label.astype(np.uint8), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)   
        mascara_predicha = cv2.resize(mascara_predicha.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        zeros = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        ones = np.ones((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))

        cmap = colors.ListedColormap(['rebeccapurple', 'yellow', 'crimson', 'lime'])
        bounds=[0,1,2,3,4]
        norm = colors.BoundaryNorm(bounds, cmap.N)
        dif = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        dif[ ( item_label == zeros ) & (mascara_predicha == zeros) ] = 0
        dif[ (item_label == ones ) & (mascara_predicha == ones) ] = 1
        dif[ (item_label == zeros) & (mascara_predicha == ones) ] = 2
        dif[ (item_label == ones) & (mascara_predicha == zeros)] = 3

        fig, (axs0, axs1, axs2, axs3) = plt.subplots(1,4, figsize = (15,15))
        x = axs0.imshow(-2.5*np.log10(x_tensor_visualizar)+zp+(5*np.log10(pix_scale)), origin='lower', cmap='viridis',vmin=27.5,vmax=28, interpolation="none")
        #x = axs0.imshow(x_tensor_visualizar)
        fig.colorbar(x, ax=axs0, fraction=0.046, pad=0.04)

        axs1.imshow(item_label, interpolation='none', origin="lower")
        axs2.imshow(mascara_predicha, interpolation='none', origin="lower", cmap="plasma")
        axs2.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs2.transAxes)
        axs3.imshow(dif, interpolation='none', origin="lower", cmap=cmap,  norm=norm)
        axs3.text(0.05, 0.95, "IOU: "+str(round(valor_iou.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs3.transAxes)
        #plt.imshow()
        
        #Save figures
        """
        fig0, ax0 = plt.subplots()
        ax0.imshow(axs0.get_images()[0].get_array(), interpolation='none', origin="lower")
        ax0.axis('off')
        fig0.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_input.png', bbox_inches='tight', pad_inches=0)
        
        fig1, ax1 = plt.subplots()
        ax1.imshow(axs1.get_images()[0].get_array(), interpolation='none', origin="lower")
        ax1.axis('off')
        fig1.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_label.png', bbox_inches='tight', pad_inches=0)
        
        fig2, ax2 = plt.subplots()
        ax2.imshow(axs2.get_images()[0].get_array(), interpolation='none', origin="lower", cmap="plasma")
        ax2.axis('off')
        ax2.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=ax2.transAxes)
        fig2.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_prediction.png', bbox_inches='tight', pad_inches=0)
        fig3, ax3 = plt.subplots()
        ax3.imshow(axs3.get_images()[0].get_array(), interpolation='none', origin="lower", cmap=cmap,  norm=norm)
        ax3.axis('off')
        ax3.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=ax3.transAxes)
        fig3.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_comparison.png', bbox_inches='tight', pad_inches=0)
        """
# Out:
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.05_NISP_J_in_background0.fits
# Magnitud: 0.05, Dice: 0.7727, IOU: 1.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.15_NISP_J_in_background0.fits
# Magnitud: 0.15, Dice: 0.7324, IOU: 0.963 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.1_NISP_J_in_background0.fits
# Magnitud: 0.1, Dice: 0.6279, IOU: 1.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.25_NISP_J_in_background0.fits
# Magnitud: 0.25, Dice: 0.0667, IOU: 1.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.2_NISP_J_in_background0.fits
# Magnitud: 0.2, Dice: 0.3158, IOU: 1.0 :
# /tmp/ipykernel_870908/2702987557.py:69: RuntimeWarning: divide by zero encountered in log10
#   x = axs0.imshow(-2.5*np.log10(x_tensor_visualizar)+zp+(5*np.log10(pix_scale)), origin='lower', cmap='viridis',vmin=27.5,vmax=28, interpolation="none")
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.4_NISP_J_in_background0.fits
# Magnitud: 0.4, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.6_NISP_J_in_background0.fits
# Magnitud: 0.6, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.8_NISP_J_in_background0.fits
# Magnitud: 0.8, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_1_NISP_J_in_background0.fits
# Magnitud: 1, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.05_NISP_J_in_background1.fits
# Magnitud: 0.05, Dice: 0.5998, IOU: 0.4543 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.15_NISP_J_in_background1.fits
# Magnitud: 0.15, Dice: 0.7638, IOU: 0.6788 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.1_NISP_J_in_background1.fits
# Magnitud: 0.1, Dice: 0.7353, IOU: 0.5888 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.25_NISP_J_in_background1.fits
# Magnitud: 0.25, Dice: 0.7059, IOU: 0.7333 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.2_NISP_J_in_background1.fits
# Magnitud: 0.2, Dice: 0.7851, IOU: 0.7308 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.4_NISP_J_in_background1.fits
# Magnitud: 0.4, Dice: 0.4524, IOU: 0.4419 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.6_NISP_J_in_background1.fits
# Magnitud: 0.6, Dice: 0.3462, IOU: 0.3214 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.8_NISP_J_in_background1.fits
# Magnitud: 0.8, Dice: 0.4375, IOU: 0.4 :

# %%
resultados_dice = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
resultados_iou = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
# Without photos
ancho = hiperparametros['ancho_imagen_deseado']
alto =hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test=0
dice_medio_test=0
iou_medio_test = 0
zp = 30.137
pix_scale = 0.1
for i in range(int(len(test_dataset))):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    #Si la máscara es vacía no intentamos segmentarla, para que no cuente en el dice
    if(np.count_nonzero(item_label)!=0):
        #Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        magnitud = item_dataset[3]
        print("Ruta: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + ", Dice: "+str(round(valor_dice.item(), 4))+" :")
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        #Mostramos imagen, mascara y mascara predicha
        item_x = cv2.resize(item_x.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        item_label = cv2.resize(item_label.astype(np.uint8), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)   
        mascara_predicha = cv2.resize(mascara_predicha.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        #fig, (axs0, axs1, axs2) = plt.subplots(1,3, figsize = (15,15))
        #axs0.imshow(item_x, interpolation='none', origin="lower")
        #axs1.imshow(item_label, interpolation='none', origin="lower")
        #axs2.imshow(mascara_predicha, interpolation='none', origin="lower")
        #plt.show()
        #guardar_imagen_plt(item_x, "item_x", i)
        #guardar_imagen_plt(item_label, "item_label", i)
        #guardar_imagen_plt(mascara_predicha, "mascara_predicha", i)
# Out:
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.05_NISP_J_in_background0.fits
# Magnitud: 0.05, Dice: 0.7727 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.15_NISP_J_in_background0.fits
# Magnitud: 0.15, Dice: 0.7324 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.1_NISP_J_in_background0.fits
# Magnitud: 0.1, Dice: 0.6279 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.25_NISP_J_in_background0.fits
# Magnitud: 0.25, Dice: 0.0667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.2_NISP_J_in_background0.fits
# Magnitud: 0.2, Dice: 0.3158 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.4_NISP_J_in_background0.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.6_NISP_J_in_background0.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_0.8_NISP_J_in_background0.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_1000_1_NISP_J_in_background0.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.05_NISP_J_in_background1.fits
# Magnitud: 0.05, Dice: 0.5998 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.15_NISP_J_in_background1.fits
# Magnitud: 0.15, Dice: 0.7638 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.1_NISP_J_in_background1.fits
# Magnitud: 0.1, Dice: 0.7353 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.25_NISP_J_in_background1.fits
# Magnitud: 0.25, Dice: 0.7059 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.2_NISP_J_in_background1.fits
# Magnitud: 0.2, Dice: 0.7851 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.4_NISP_J_in_background1.fits
# Magnitud: 0.4, Dice: 0.4524 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.6_NISP_J_in_background1.fits
# Magnitud: 0.6, Dice: 0.3462 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_0.8_NISP_J_in_background1.fits
# Magnitud: 0.8, Dice: 0.4375 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_100_1_NISP_J_in_background1.fits
# Magnitud: 1, Dice: 0.1622 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.05_NISP_J_in_background2.fits
# Magnitud: 0.05, Dice: 0.6893 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.15_NISP_J_in_background2.fits
# Magnitud: 0.15, Dice: 0.7253 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.1_NISP_J_in_background2.fits
# Magnitud: 0.1, Dice: 0.8484 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.25_NISP_J_in_background2.fits
# Magnitud: 0.25, Dice: 0.5301 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.2_NISP_J_in_background2.fits
# Magnitud: 0.2, Dice: 0.5534 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.4_NISP_J_in_background2.fits
# Magnitud: 0.4, Dice: 0.4138 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.6_NISP_J_in_background2.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_0.8_NISP_J_in_background2.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_101_1_NISP_J_in_background2.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.05_NISP_J_in_background3.fits
# Magnitud: 0.05, Dice: 0.375 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.15_NISP_J_in_background3.fits
# Magnitud: 0.15, Dice: 0.5956 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.1_NISP_J_in_background3.fits
# Magnitud: 0.1, Dice: 0.6838 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.25_NISP_J_in_background3.fits
# Magnitud: 0.25, Dice: 0.6939 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.2_NISP_J_in_background3.fits
# Magnitud: 0.2, Dice: 0.6516 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.4_NISP_J_in_background3.fits
# Magnitud: 0.4, Dice: 0.4112 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.6_NISP_J_in_background3.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_0.8_NISP_J_in_background3.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_102_1_NISP_J_in_background3.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.05_NISP_J_in_background4.fits
# Magnitud: 0.05, Dice: 0.7257 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.15_NISP_J_in_background4.fits
# Magnitud: 0.15, Dice: 0.6087 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.1_NISP_J_in_background4.fits
# Magnitud: 0.1, Dice: 0.71 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.25_NISP_J_in_background4.fits
# Magnitud: 0.25, Dice: 0.7423 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.2_NISP_J_in_background4.fits
# Magnitud: 0.2, Dice: 0.6667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_103_0.4_NISP_J_in_background4.fits
# Magnitud: 0.4, Dice: 0.5 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved
:
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_107_1_NISP_J_in_background8.fits
# Magnitud: 1, Dice: 0.8462 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.05_NISP_J_in_background9.fits
# Magnitud: 0.05, Dice: 0.8596 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.15_NISP_J_in_background9.fits
# Magnitud: 0.15, Dice: 0.8075 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.1_NISP_J_in_background9.fits
# Magnitud: 0.1, Dice: 0.8968 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.25_NISP_J_in_background9.fits
# Magnitud: 0.25, Dice: 0.8067 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.2_NISP_J_in_background9.fits
# Magnitud: 0.2, Dice: 0.813 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.4_NISP_J_in_background9.fits
# Magnitud: 0.4, Dice: 0.8169 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.6_NISP_J_in_background9.fits
# Magnitud: 0.6, Dice: 0.75 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_0.8_NISP_J_in_background9.fits
# Magnitud: 0.8, Dice: 0.75 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_108_1_NISP_J_in_background9.fits
# Magnitud: 1, Dice: 0.6923 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.05_NISP_J_in_background10.fits
# Magnitud: 0.05, Dice: 0.5221 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.15_NISP_J_in_background10.fits
# Magnitud: 0.15, Dice: 0.2716 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.1_NISP_J_in_background10.fits
# Magnitud: 0.1, Dice: 0.3423 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.25_NISP_J_in_background10.fits
# Magnitud: 0.25, Dice: 0.2 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.2_NISP_J_in_background10.fits
# Magnitud: 0.2, Dice: 0.3544 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.4_NISP_J_in_background10.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.6_NISP_J_in_background10.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_0.8_NISP_J_in_background10.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_109_1_NISP_J_in_background10.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.05_NISP_J_in_background11.fits
# Magnitud: 0.05, Dice: 0.393 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.15_NISP_J_in_background11.fits
# Magnitud: 0.15, Dice: 0.6807 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.1_NISP_J_in_background11.fits
# Magnitud: 0.1, Dice: 0.6978 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.25_NISP_J_in_background11.fits
# Magnitud: 0.25, Dice: 0.6627 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.2_NISP_J_in_background11.fits
# Magnitud: 0.2, Dice: 0.6335 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.4_NISP_J_in_background11.fits
# Magnitud: 0.4, Dice: 0.5455 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.6_NISP_J_in_background11.fits
# Magnitud: 0.6, Dice: 0.3333 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_0.8_NISP_J_in_background11.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_10_1_NISP_J_in_background11.fits
# Magnitud: 1, Dice: 0.0465 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.05_NISP_J_in_background12.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.15_NISP_J_in_background12.fits
# Magnitud: 0.15, Dice: 0.2241 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.1_NISP_J_in_background12.fits
# Magnitud: 0.1, Dice: 0.4986 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.25_NISP_J_in_background12.fits
# Magnitud: 0.25, Dice: 0.2585 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.2_NISP_J_in_background12.fits
# Magnitud: 0.2, Dice: 0.3398 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.4_NISP_J_in_background12.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.6_NISP_J_in_background12.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_0.8_NISP_J_in_background12.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_110_1_NISP_J_in_background12.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.05_NISP_J_in_background13.fits
# Magnitud: 0.05, Dice: 0.8097 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.15_NISP_J_in_background13.fits
# Magnitud: 0.15, Dice: 0.777 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_111_0.1_NISP_J_in_background13.fits
# Magnitud: 0.1, Dice: 0.8223 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved
:
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_140_0.2_NISP_J_in_background45.fits
# Magnitud: 0.2, Dice: 0.7005 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_140_0.4_NISP_J_in_background45.fits
# Magnitud: 0.4, Dice: 0.3958 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_140_0.6_NISP_J_in_background45.fits
# Magnitud: 0.6, Dice: 0.2424 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_140_0.8_NISP_J_in_background45.fits
# Magnitud: 0.8, Dice: 0.0 :
# ...
# Magnitud: 0.2, Dice: 0.8214 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_265_0.4_NISP_J_in_background183.fits
# Magnitud: 0.4, Dice: 0.8219 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_265_0.6_NISP_J_in_background183.fits
# Magnitud: 0.6, Dice: 0.7451 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_265_0.8_NISP_J_in_background183.fits
# Magnitud: 0.8, Dice: 0.6154 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_265_1_NISP_J_in_background183.fits
# Magnitud: 1, Dice: 0.6 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.05_NISP_J_in_background184.fits
# Magnitud: 0.05, Dice: 0.8604 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.15_NISP_J_in_background184.fits
# Magnitud: 0.15, Dice: 0.8083 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.1_NISP_J_in_background184.fits
# Magnitud: 0.1, Dice: 0.8975 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.25_NISP_J_in_background184.fits
# Magnitud: 0.25, Dice: 0.8947 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.2_NISP_J_in_background184.fits
# Magnitud: 0.2, Dice: 0.9008 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.4_NISP_J_in_background184.fits
# Magnitud: 0.4, Dice: 0.8611 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.6_NISP_J_in_background184.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_0.8_NISP_J_in_background184.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_266_1_NISP_J_in_background184.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.05_NISP_J_in_background185.fits
# Magnitud: 0.05, Dice: 0.8019 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.15_NISP_J_in_background185.fits
# Magnitud: 0.15, Dice: 0.8266 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.1_NISP_J_in_background185.fits
# Magnitud: 0.1, Dice: 0.8212 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.25_NISP_J_in_background185.fits
# Magnitud: 0.25, Dice: 0.8118 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.2_NISP_J_in_background185.fits
# Magnitud: 0.2, Dice: 0.8685 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.4_NISP_J_in_background185.fits
# Magnitud: 0.4, Dice: 0.6622 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.6_NISP_J_in_background185.fits
# Magnitud: 0.6, Dice: 0.4 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_0.8_NISP_J_in_background185.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_267_1_NISP_J_in_background185.fits
# Magnitud: 1, Dice: 0.24 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.05_NISP_J_in_background186.fits
# Magnitud: 0.05, Dice: 0.7329 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.15_NISP_J_in_background186.fits
# Magnitud: 0.15, Dice: 0.8205 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.1_NISP_J_in_background186.fits
# Magnitud: 0.1, Dice: 0.7895 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.25_NISP_J_in_background186.fits
# Magnitud: 0.25, Dice: 0.75 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.2_NISP_J_in_background186.fits
# Magnitud: 0.2, Dice: 0.7857 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.4_NISP_J_in_background186.fits
# Magnitud: 0.4, Dice: 0.4262 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.6_NISP_J_in_background186.fits
# Magnitud: 0.6, Dice: 0.1667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_0.8_NISP_J_in_background186.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_268_1_NISP_J_in_background186.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.05_NISP_J_in_background187.fits
# Magnitud: 0.05, Dice: 0.1446 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.15_NISP_J_in_background187.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.1_NISP_J_in_background187.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.25_NISP_J_in_background187.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.2_NISP_J_in_background187.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_269_0.4_NISP_J_in_background187.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.05_NISP_J_in_background188.fits
# Magnitud: 0.05, Dice: 0.7319 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.15_NISP_J_in_background188.fits
# Magnitud: 0.15, Dice: 0.7821 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.1_NISP_J_in_background188.fits
# Magnitud: 0.1, Dice: 0.7978 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.25_NISP_J_in_background188.fits
# Magnitud: 0.25, Dice: 0.7576 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.2_NISP_J_in_background188.fits
# Magnitud: 0.2, Dice: 0.8049 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.4_NISP_J_in_background188.fits
# Magnitud: 0.4, Dice: 0.7414 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.6_NISP_J_in_background188.fits
# Magnitud: 0.6, Dice: 0.6857 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_0.8_NISP_J_in_background188.fits
# Magnitud: 0.8, Dice: 0.3556 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_26_1_NISP_J_in_background188.fits
# Magnitud: 1, Dice: 0.5185 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.05_NISP_J_in_background189.fits
# Magnitud: 0.05, Dice: 0.6685 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.15_NISP_J_in_background189.fits
# Magnitud: 0.15, Dice: 0.6839 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.1_NISP_J_in_background189.fits
# Magnitud: 0.1, Dice: 0.5311 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.25_NISP_J_in_background189.fits
# Magnitud: 0.25, Dice: 0.1042 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.2_NISP_J_in_background189.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.4_NISP_J_in_background189.fits
# Magnitud: 0.4, Dice: 0.3038 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.6_NISP_J_in_background189.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_0.8_NISP_J_in_background189.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_270_1_NISP_J_in_background189.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.05_NISP_J_in_background190.fits
# Magnitud: 0.05, Dice: 0.1435 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.15_NISP_J_in_background190.fits
# Magnitud: 0.15, Dice: 0.6747 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.1_NISP_J_in_background190.fits
# Magnitud: 0.1, Dice: 0.477 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.25_NISP_J_in_background190.fits
# Magnitud: 0.25, Dice: 0.5778 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.2_NISP_J_in_background190.fits
# Magnitud: 0.2, Dice: 0.7086 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.4_NISP_J_in_background190.fits
# Magnitud: 0.4, Dice: 0.6389 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.6_NISP_J_in_background190.fits
# Magnitud: 0.6, Dice: 0.6047 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_0.8_NISP_J_in_background190.fits
# Magnitud: 0.8, Dice: 0.4571 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_271_1_NISP_J_in_background190.fits
# Magnitud: 1, Dice: 0.4138 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.05_NISP_J_in_background191.fits
# Magnitud: 0.05, Dice: 0.6437 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.15_NISP_J_in_background191.fits
# Magnitud: 0.15, Dice: 0.5422 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.1_NISP_J_in_background191.fits
# Magnitud: 0.1, Dice: 0.6154 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.25_NISP_J_in_background191.fits
# Magnitud: 0.25, Dice: 0.486 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.2_NISP_J_in_background191.fits
# Magnitud: 0.2, Dice: 0.5426 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.4_NISP_J_in_background191.fits
# Magnitud: 0.4, Dice: 0.3 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.6_NISP_J_in_background191.fits
# Magnitud: 0.6, Dice: 0.4651 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_0.8_NISP_J_in_background191.fits
# Magnitud: 0.8, Dice: 0.1905 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_272_1_NISP_J_in_background191.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.05_NISP_J_in_background192.fits
# Magnitud: 0.05, Dice: 0.2177 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.15_NISP_J_in_background192.fits
# Magnitud: 0.15, Dice: 0.5238 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.1_NISP_J_in_background192.fits
# Magnitud: 0.1, Dice: 0.623 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.25_NISP_J_in_background192.fits
# Magnitud: 0.25, Dice: 0.4561 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.2_NISP_J_in_background192.fits
# Magnitud: 0.2, Dice: 0.5217 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.4_NISP_J_in_background192.fits
# Magnitud: 0.4, Dice: 0.0588 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.6_NISP_J_in_background192.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_0.8_NISP_J_in_background192.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_273_1_NISP_J_in_background192.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.05_NISP_J_in_background193.fits
# Magnitud: 0.05, Dice: 0.5737 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.15_NISP_J_in_background193.fits
# Magnitud: 0.15, Dice: 0.5312 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.1_NISP_J_in_background193.fits
# Magnitud: 0.1, Dice: 0.4777 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.25_NISP_J_in_background193.fits
# Magnitud: 0.25, Dice: 0.5229 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.2_NISP_J_in_background193.fits
# Magnitud: 0.2, Dice: 0.5251 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.4_NISP_J_in_background193.fits
# Magnitud: 0.4, Dice: 0.4051 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.6_NISP_J_in_background193.fits
# Magnitud: 0.6, Dice: 0.566 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_0.8_NISP_J_in_background193.fits
# Magnitud: 0.8, Dice: 0.6 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_274_1_NISP_J_in_background193.fits
# Magnitud: 1, Dice: 0.1667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.05_NISP_J_in_background194.fits
# Magnitud: 0.05, Dice: 0.8145 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.15_NISP_J_in_background194.fits
# Magnitud: 0.15, Dice: 0.4771 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.1_NISP_J_in_background194.fits
# Magnitud: 0.1, Dice: 0.5833 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.25_NISP_J_in_background194.fits
# Magnitud: 0.25, Dice: 0.3077 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.2_NISP_J_in_background194.fits
# Magnitud: 0.2, Dice: 0.4286 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_275_0.4_NISP_J_in_background194.fits
# Magnitud: 0.4, Dice: 0.2857 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.05_NISP_J_in_background195.fits
# Magnitud: 0.05, Dice: 0.8173 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.15_NISP_J_in_background195.fits
# Magnitud: 0.15, Dice: 0.8795 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.1_NISP_J_in_background195.fits
# Magnitud: 0.1, Dice: 0.8825 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.25_NISP_J_in_background195.fits
# Magnitud: 0.25, Dice: 0.7394 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.2_NISP_J_in_background195.fits
# Magnitud: 0.2, Dice: 0.9072 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.4_NISP_J_in_background195.fits
# Magnitud: 0.4, Dice: 0.7679 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.6_NISP_J_in_background195.fits
# Magnitud: 0.6, Dice: 0.4231 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_0.8_NISP_J_in_background195.fits
# Magnitud: 0.8, Dice: 0.4211 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_276_1_NISP_J_in_background195.fits
# Magnitud: 1, Dice: 0.6667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.05_NISP_J_in_background196.fits
# Magnitud: 0.05, Dice: 0.4395 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.15_NISP_J_in_background196.fits
# Magnitud: 0.15, Dice: 0.4277 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.1_NISP_J_in_background196.fits
# Magnitud: 0.1, Dice: 0.5345 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.25_NISP_J_in_background196.fits
# Magnitud: 0.25, Dice: 0.175 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.2_NISP_J_in_background196.fits
# Magnitud: 0.2, Dice: 0.1765 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.4_NISP_J_in_background196.fits
# Magnitud: 0.4, Dice: 0.0645 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.6_NISP_J_in_background196.fits
# Magnitud: 0.6, Dice: 0.1905 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_0.8_NISP_J_in_background196.fits
# Magnitud: 0.8, Dice: 0.2105 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_277_1_NISP_J_in_background196.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.05_NISP_J_in_background197.fits
# Magnitud: 0.05, Dice: 0.529 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.15_NISP_J_in_background197.fits
# Magnitud: 0.15, Dice: 0.8585 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.1_NISP_J_in_background197.fits
# Magnitud: 0.1, Dice: 0.8462 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.25_NISP_J_in_background197.fits
# Magnitud: 0.25, Dice: 0.8164 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.2_NISP_J_in_background197.fits
# Magnitud: 0.2, Dice: 0.853 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.4_NISP_J_in_background197.fits
# Magnitud: 0.4, Dice: 0.8621 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.6_NISP_J_in_background197.fits
# Magnitud: 0.6, Dice: 0.8343 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_0.8_NISP_J_in_background197.fits
# Magnitud: 0.8, Dice: 0.6833 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_278_1_NISP_J_in_background197.fits
# Magnitud: 1, Dice: 0.7368 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.05_NISP_J_in_background198.fits
# Magnitud: 0.05, Dice: 0.4401 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.15_NISP_J_in_background198.fits
# Magnitud: 0.15, Dice: 0.8421 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.1_NISP_J_in_background198.fits
# Magnitud: 0.1, Dice: 0.4058 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.25_NISP_J_in_background198.fits
# Magnitud: 0.25, Dice: 0.4667 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.2_NISP_J_in_background198.fits
# Magnitud: 0.2, Dice: 0.625 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.4_NISP_J_in_background198.fits
# Magnitud: 0.4, Dice: 0.7234 :
# Ruta: galaxies_test_NISP_J/galaxy_and_stream_convolved_279_0.6_NISP_J_in_background198.fits
# Magnitud: 0.6, Dice: 0.8 :

# %%
dice_test_medio_total=dice_medio_test/pasos_test
print("Dice_medio_total="+str(dice_test_medio_total))
# Out:
# Dice_medio_total=0.46761508403626034

# %%
iou_test_medio_total=iou_medio_test/pasos_test
print("IOU_medio_total="+str(iou_test_medio_total))
# Out:
# IOU_medio_total=nan

# %%
# Filtrar NaNs y calcular la media para resultados_dice
dices_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_dice.values()]
print(dices_medios_por_magnitud)
# Filtrar NaNs y calcular la media para resultados_iou
ious_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_iou.values()]
print(ious_medios_por_magnitud)
# Out:
# [0.6064912107721645, 0.6342242063361813, 0.6155211364455295, 0.5702805604992641, 0.5319775812100941, 0.4371655221990089, 0.32361163457757547, 0.2490480274279067, 0.20794100350237146]
# [0.8316741889805963, 0.8347166563893101, 0.8267957582914581, 0.7988071969661273, 0.7944624589240932, 0.7155844226612577, 0.6518339595106775, 0.6280552890212809, 0.6119030955636385]

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in dices_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(dices_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('NISP J Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('Dice', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_870908/3379223844.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in ious_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(ious_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('NISP J Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('IOU', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_870908/1371107044.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)
