# %%
import copy
import cv2
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import os
import seaborn as sns
from astropy.io import fits
import torch
from torch.utils.data import Dataset
from torchmetrics import Dice
from torchmetrics import Dice, JaccardIndex
import segmentation_models_pytorch as smp
# Out:
# /home2/dario/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
hiperparametros = {'nombre_notebook': 'Evaluation_VIS_1000_v5imgs.ipynb',
                    'nombre_experimento' : 'Evaluation_VIS_1000_v5imgs',
                    'nombre_mejor_modelo_entrenado' : 'VIS_1000imgs_v5',
                    'device' : torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
                    'ruta_galaxias' : 'galaxies_test_VIS/galaxy_and_stream_convolved*.fits',
                    'ruta_mascaras' : '../masks_train_VIS/mask_',
                    'ancho_imagen_original' : 600,
                    'alto_imagen_original' : 600,
                    'ancho_imagen_deseado' : 608,
                    'alto_imagen_deseado' : 608}

# %%
def get_galaxy_number(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[4]

def get_galaxy_magnitude(galaxy_name:str):
    return os.path.basename(galaxy_name).split('_')[5]

def normalize_01(inp: np.ndarray):
    """Squash image input to the value range [0, 1] (no clipping)"""
    inp_out = (inp - np.min(inp)) / np.ptp(inp)
    return inp_out

def imagen_logaritmica(img: np.ndarray)->np.ndarray:
    """
    Escalamos de forma logarítmica la imagen para aumentar el contraste
    """
    img_log = np.log(img, where=(img>0))
    valor_minimo = np.min(img_log)
    np.putmask(img_log, img!=0, img_log+abs(valor_minimo))
    return img_log

# %%
class MyDataset(Dataset):
    """
    Dataset básico sin ningún tipo de augmentation
    """
    def __init__(self, galaxias_con_colas_de_marea, transform=None):
        """
        Constructor del dataset
        @param galaxias_con_colas_de_marea: Lista de rutas a los ficheros que contienen los datos de las galaxias
        """
        self.galaxias_con_colas_de_marea = galaxias_con_colas_de_marea
        self.transform=transform

    def __getitem__(self, index):
        #Abrimos la imagen de la galaxia con cola de marea
        ruta = self.galaxias_con_colas_de_marea[index]
        magnitud_real = get_galaxy_magnitude(ruta)
        galaxy_fits = fits.open(self.galaxias_con_colas_de_marea[index])
        x = galaxy_fits[0].data.astype(np.float32)
        #Abrimos la mascara correspondiente a la imagen
        numero_galaxia = get_galaxy_number(self.galaxias_con_colas_de_marea[index])
        magnitud_galaxia = get_galaxy_magnitude(self.galaxias_con_colas_de_marea[index])
        
        y = np.array(cv2.imread(hiperparametros['ruta_mascaras']+str(numero_galaxia)+"_"+str(magnitud_galaxia)+".png",0)).astype(np.float32)
        #x = normalize_01(x)
        x_tensor_visualizar = copy.deepcopy(x)
        x = imagen_logaritmica(x)

        x = normalize_01(x)
        # Assuming 'input_item' is your input image
        x = cv2.resize(x, (hiperparametros['ancho_imagen_deseado'], hiperparametros['alto_imagen_deseado']))
        y = cv2.resize(y, (hiperparametros['ancho_imagen_deseado'], hiperparametros['alto_imagen_deseado']))
        if(self.transform is not None):
            augmented = self.transform(image=x, mask=y)
            x_tensor= augmented["image"]
            y_tensor= augmented["mask"].long()
        else:
            x_tensor = torch.from_numpy(x).float()
            x_tensor=torch.unsqueeze(x_tensor, dim=0)
            y_tensor = torch.from_numpy(y).long()
        
        #Hacemos reshape de los tensores
        y_tensor=torch.unsqueeze(y_tensor, dim=0)
        return x_tensor, y_tensor, ruta, magnitud_real, x_tensor_visualizar
    
    def __len__(self):
        """
        Devuelve la longitud del dataset
        """
        return len(self.galaxias_con_colas_de_marea)

# %%
dice = Dice(num_classes=2, average='macro', ignore_index=0)
iou = JaccardIndex(task='multiclass', num_classes=2, average='macro', ignore_index=0)
imagenes_test = glob.glob(hiperparametros['ruta_galaxias'])
imagenes_test.sort()
#Cargamos el dataset de test
test_dataset= MyDataset(imagenes_test)
print("Number of valid images: " + str(len(imagenes_test)))
device = hiperparametros['device']
#dice.to(device)
# Out:
# Number of valid images: 1797

# %%
unet = smp.Unet(
    encoder_name="resnet18",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=2,                      # model output channels (number of classes in your dataset)
)

# %%
#Cargamos el modelo previamente entrenado
ruta_modelo = hiperparametros['nombre_mejor_modelo_entrenado']
mejor_modelo = unet
mejor_modelo.load_state_dict(torch.load(ruta_modelo))
mejor_modelo.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
resultados_dice = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
resultados_iou = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
# With photos
ancho = hiperparametros['ancho_imagen_deseado']
alto =hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test=0
dice_medio_test=0
iou_medio_test = 0
zp = 30.132 # TODO Preguntar a Fer
pix_scale = 0.1 # TODO Preguntar a Fer
for i in range(int(len(test_dataset) * 0.01)):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    x_tensor_visualizar = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    #Si la máscara es vacía no intentamos segmentarla, para que no cuente en el dice
    if(np.count_nonzero(item_label)!=0):
        #Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        magnitud = item_dataset[3]
        print("Ruta: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + ", Dice: "+str(round(valor_dice.item(), 4))+", IOU: "+str(round(valor_iou.item(), 4))+" :")
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        #Mostramos imagen, mascara y mascara predicha
        item_x = cv2.resize(item_x.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)
        
        item_label = cv2.resize(item_label.astype(np.uint8), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)   
        mascara_predicha = cv2.resize(mascara_predicha.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        zeros = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        ones = np.ones((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))

        cmap = colors.ListedColormap(['rebeccapurple', 'yellow', 'crimson', 'lime'])
        bounds=[0,1,2,3,4]
        norm = colors.BoundaryNorm(bounds, cmap.N)
        dif = np.zeros((hiperparametros['ancho_imagen_original'], hiperparametros['ancho_imagen_original']))
        dif[ ( item_label == zeros ) & (mascara_predicha == zeros) ] = 0
        dif[ (item_label == ones ) & (mascara_predicha == ones) ] = 1
        dif[ (item_label == zeros) & (mascara_predicha == ones) ] = 2
        dif[ (item_label == ones) & (mascara_predicha == zeros)] = 3

        fig, (axs0, axs1, axs2, axs3) = plt.subplots(1,4, figsize = (15,15))
        x = axs0.imshow(-2.5*np.log10(x_tensor_visualizar)+zp+(5*np.log10(pix_scale)), origin='lower', cmap='viridis',vmin=15,vmax=30, interpolation="none")
        #x = axs0.imshow(x_tensor_visualizar)
        fig.colorbar(x, ax=axs0, fraction=0.046, pad=0.04)

        axs1.imshow(item_label, interpolation='none', origin="lower")
        axs2.imshow(mascara_predicha, interpolation='none', origin="lower", cmap="plasma")
        axs2.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs2.transAxes)
        axs3.imshow(dif, interpolation='none', origin="lower", cmap=cmap,  norm=norm)
        axs3.text(0.05, 0.95, "IOU: "+str(round(valor_iou.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=axs3.transAxes)
        #plt.imshow()
        
        #Save figures
        """
        fig0, ax0 = plt.subplots()
        ax0.imshow(axs0.get_images()[0].get_array(), interpolation='none', origin="lower")
        ax0.axis('off')
        fig0.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_input.png', bbox_inches='tight', pad_inches=0)
        
        fig1, ax1 = plt.subplots()
        ax1.imshow(axs1.get_images()[0].get_array(), interpolation='none', origin="lower")
        ax1.axis('off')
        fig1.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_label.png', bbox_inches='tight', pad_inches=0)
        
        fig2, ax2 = plt.subplots()
        ax2.imshow(axs2.get_images()[0].get_array(), interpolation='none', origin="lower", cmap="plasma")
        ax2.axis('off')
        ax2.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=ax2.transAxes)
        fig2.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_prediction.png', bbox_inches='tight', pad_inches=0)
        fig3, ax3 = plt.subplots()
        ax3.imshow(axs3.get_images()[0].get_array(), interpolation='none', origin="lower", cmap=cmap,  norm=norm)
        ax3.axis('off')
        ax3.text(0.05, 0.95, "Dice: "+str(round(valor_dice.item(), 4)), color='white', fontsize=20, ha='left', va='top', transform=ax3.transAxes)
        fig3.figure.savefig("images_paper_vis/"+ item_dataset[2].split('/')[-1]+'_comparison.png', bbox_inches='tight', pad_inches=0)
        """
# Out:
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_background0.fits
# Magnitud: 0.05, Dice: 0.7043, IOU: 0.9579 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_background0.fits
# Magnitud: 0.15, Dice: 0.2643, IOU: 1.0 :
# /tmp/ipykernel_1526952/2866807023.py:69: RuntimeWarning: divide by zero encountered in log10
#   x = axs0.imshow(-2.5*np.log10(x_tensor_visualizar)+zp+(5*np.log10(pix_scale)), origin='lower', cmap='viridis',vmin=15,vmax=30, interpolation="none")
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_background0.fits
# Magnitud: 0.1, Dice: 0.6723, IOU: 0.9467 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_background0.fits
# Magnitud: 0.25, Dice: 0.0, IOU: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_background0.fits
# Magnitud: 0.2, Dice: 0.0111, IOU: 0.0476 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_background0.fits
# Magnitud: 0.4, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_background0.fits
# Magnitud: 0.6, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_background0.fits
# Magnitud: 0.8, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_background0.fits
# Magnitud: 1, Dice: 0.0, IOU: nan :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_background1.fits
# Magnitud: 0.05, Dice: 0.3198, IOU: 0.2705 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_background1.fits
# Magnitud: 0.15, Dice: 0.7503, IOU: 0.6624 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_background1.fits
# Magnitud: 0.1, Dice: 0.569, IOU: 0.5869 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_background1.fits
# Magnitud: 0.25, Dice: 0.634, IOU: 0.6492 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_background1.fits
# Magnitud: 0.2, Dice: 0.7184, IOU: 0.6435 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_background1.fits
# Magnitud: 0.4, Dice: 0.5928, IOU: 0.6376 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_background1.fits
# Magnitud: 0.6, Dice: 0.339, IOU: 0.4505 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_background1.fits
# Magnitud: 0.8, Dice: 0.1828, IOU: 0.2982 :

# %%
resultados_dice = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
resultados_iou = {
    '0.05':[],
    '0.1':[],
    '0.15':[],
    '0.2':[],
    '0.25':[],
    '0.4':[],
    '0.6':[],
    '0.8':[],
    '1':[],
}
# Without photos
ancho = hiperparametros['ancho_imagen_deseado']
alto =hiperparametros['alto_imagen_deseado']
mejor_modelo.eval()
pasos_test=0
dice_medio_test=0
iou_medio_test = 0
zp = 30.137
pix_scale = 0.1
for i in range(int(len(test_dataset))):
    item_dataset = test_dataset.__getitem__(i)
    item_x = item_dataset[0].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    item_label = item_dataset[1].reshape((1,1,ancho,alto)).cpu().detach().squeeze().numpy()
    #Si la máscara es vacía no intentamos segmentarla, para que no cuente en el dice
    if(np.count_nonzero(item_label)!=0):
        #Obtenemos predicción de la red
        prediccion_item_tensor = mejor_modelo(item_dataset[0].reshape((1,1,ancho,alto)).to(device)).cpu().detach().squeeze()   
        mascara_predicha = torch.argmax(prediccion_item_tensor, dim=0).numpy()
        valor_dice = dice(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        valor_iou = iou(torch.from_numpy(item_label), torch.from_numpy(mascara_predicha))
        magnitud = item_dataset[3]
        print("Ruta: "+item_dataset[2]+ "\nMagnitud: "+ magnitud + ", Dice: "+str(round(valor_dice.item(), 4))+" :")
        resultados_dice[magnitud].append(valor_dice.item())
        resultados_iou[magnitud].append(valor_iou.item())
        dice_medio_test += valor_dice.item()
        iou_medio_test += valor_iou.item()
        pasos_test += 1
        #Mostramos imagen, mascara y mascara predicha
        item_x = cv2.resize(item_x.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        item_label = cv2.resize(item_label.astype(np.uint8), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)   
        mascara_predicha = cv2.resize(mascara_predicha.astype(np.float32), (hiperparametros['ancho_imagen_original'], hiperparametros['alto_imagen_original']), interpolation = cv2.INTER_NEAREST)     
        #fig, (axs0, axs1, axs2) = plt.subplots(1,3, figsize = (15,15))
        #axs0.imshow(item_x, interpolation='none', origin="lower")
        #axs1.imshow(item_label, interpolation='none', origin="lower")
        #axs2.imshow(mascara_predicha, interpolation='none', origin="lower")
        #plt.show()
        #guardar_imagen_plt(item_x, "item_x", i)
        #guardar_imagen_plt(item_label, "item_label", i)
        #guardar_imagen_plt(mascara_predicha, "mascara_predicha", i)
# Out:
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.05_VIS_in_background0.fits
# Magnitud: 0.05, Dice: 0.7043 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.15_VIS_in_background0.fits
# Magnitud: 0.15, Dice: 0.2643 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.1_VIS_in_background0.fits
# Magnitud: 0.1, Dice: 0.6723 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.25_VIS_in_background0.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.2_VIS_in_background0.fits
# Magnitud: 0.2, Dice: 0.0111 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.4_VIS_in_background0.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.6_VIS_in_background0.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_0.8_VIS_in_background0.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_1000_1_VIS_in_background0.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.05_VIS_in_background1.fits
# Magnitud: 0.05, Dice: 0.3198 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.15_VIS_in_background1.fits
# Magnitud: 0.15, Dice: 0.7503 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.1_VIS_in_background1.fits
# Magnitud: 0.1, Dice: 0.569 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.25_VIS_in_background1.fits
# Magnitud: 0.25, Dice: 0.634 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.2_VIS_in_background1.fits
# Magnitud: 0.2, Dice: 0.7184 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.4_VIS_in_background1.fits
# Magnitud: 0.4, Dice: 0.5928 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.6_VIS_in_background1.fits
# Magnitud: 0.6, Dice: 0.339 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_0.8_VIS_in_background1.fits
# Magnitud: 0.8, Dice: 0.1828 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_100_1_VIS_in_background1.fits
# Magnitud: 1, Dice: 0.2384 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.05_VIS_in_background2.fits
# Magnitud: 0.05, Dice: 0.0351 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.15_VIS_in_background2.fits
# Magnitud: 0.15, Dice: 0.7746 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.1_VIS_in_background2.fits
# Magnitud: 0.1, Dice: 0.7261 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.25_VIS_in_background2.fits
# Magnitud: 0.25, Dice: 0.7815 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.2_VIS_in_background2.fits
# Magnitud: 0.2, Dice: 0.7751 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.4_VIS_in_background2.fits
# Magnitud: 0.4, Dice: 0.3871 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.6_VIS_in_background2.fits
# Magnitud: 0.6, Dice: 0.0093 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_0.8_VIS_in_background2.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_101_1_VIS_in_background2.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.15_VIS_in_background3.fits
# Magnitud: 0.15, Dice: 0.4312 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.25_VIS_in_background3.fits
# Magnitud: 0.25, Dice: 0.6638 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.2_VIS_in_background3.fits
# Magnitud: 0.2, Dice: 0.603 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.4_VIS_in_background3.fits
# Magnitud: 0.4, Dice: 0.6911 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.6_VIS_in_background3.fits
# Magnitud: 0.6, Dice: 0.566 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_0.8_VIS_in_background3.fits
# Magnitud: 0.8, Dice: 0.4895 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_102_1_VIS_in_background3.fits
# Magnitud: 1, Dice: 0.2353 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.05_VIS_in_background4.fits
# Magnitud: 0.05, Dice: 0.667 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.15_VIS_in_background4.fits
# Magnitud: 0.15, Dice: 0.4049 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.1_VIS_in_background4.fits
# Magnitud: 0.1, Dice: 0.3432 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.25_VIS_in_background4.fits
# Magnitud: 0.25, Dice: 0.5215 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.2_VIS_in_background4.fits
# Magnitud: 0.2, Dice: 0.5369 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.4_VIS_in_background4.fits
# Magnitud: 0.4, Dice: 0.4059 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.6_VIS_in_background4.fits
# Magnitud: 0.6, Dice: 0.0805 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_0.8_VIS_in_background4.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_103_1_VIS_in_background4.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.05_VIS_in_background5.fits
# Magnitud: 0.05, Dice: 0.4973 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.15_VIS_in_background5.fits
# Magnitud: 0.15, Dice: 0.5791 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.1_VIS_in_background5.fits
# Magnitud: 0.1, Dice: 0.601 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.25_VIS_in_background5.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.2_VIS_in_background5.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.4_VIS_in_background5.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.6_VIS_in_background5.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_0.8_VIS_in_background5.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_104_1_VIS_in_background5.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.05_VIS_in_background6.fits
# Magnitud: 0.05, Dice: 0.8384 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.15_VIS_in_background6.fits
# Magnitud: 0.15, Dice: 0.8498 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.1_VIS_in_background6.fits
# Magnitud: 0.1, Dice: 0.833 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.25_VIS_in_background6.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.2_VIS_in_background6.fits
# Magnitud: 0.2, Dice: 0.0141 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.4_VIS_in_background6.fits
# Magnitud: 0.4, Dice: 0.6165 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.6_VIS_in_background6.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_0.8_VIS_in_background6.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_105_1_VIS_in_background6.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.05_VIS_in_background7.fits
# Magnitud: 0.05, Dice: 0.6386 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.15_VIS_in_background7.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.1_VIS_in_background7.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.25_VIS_in_background7.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.2_VIS_in_background7.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.4_VIS_in_background7.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.6_VIS_in_background7.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_0.8_VIS_in_background7.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_106_1_VIS_in_background7.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.15_VIS_in_background8.fits
# Magnitud: 0.15, Dice: 0.3276 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.1_VIS_in_background8.fits
# Magnitud: 0.1, Dice: 0.3449 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.25_VIS_in_background8.fits
# Magnitud: 0.25, Dice: 0.7082 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.2_VIS_in_background8.fits
# Magnitud: 0.2, Dice: 0.5049 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.4_VIS_in_background8.fits
# Magnitud: 0.4, Dice: 0.7092 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.6_VIS_in_background8.fits
# Magnitud: 0.6, Dice: 0.6936 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_0.8_VIS_in_background8.fits
# Magnitud: 0.8, Dice: 0.631 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_107_1_VIS_in_background8.fits
# Magnitud: 1, Dice: 0.5904 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.05_VIS_in_background9.fits
# Magnitud: 0.05, Dice: 0.3107 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.15_VIS_in_background9.fits
# Magnitud: 0.15, Dice: 0.629 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.1_VIS_in_background9.fits
# Magnitud: 0.1, Dice: 0.6303 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.25_VIS_in_background9.fits
# Magnitud: 0.25, Dice: 0.5076 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.2_VIS_in_background9.fits
# Magnitud: 0.2, Dice: 0.5051 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.4_VIS_in_background9.fits
# Magnitud: 0.4, Dice: 0.4455 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.6_VIS_in_background9.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_0.8_VIS_in_background9.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_108_1_VIS_in_background9.fits
# Magnitud: 1, Dice: 0.075 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.05_VIS_in_background10.fits
# Magnitud: 0.05, Dice: 0.2333 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.15_VIS_in_background10.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.1_VIS_in_background10.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.25_VIS_in_background10.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.2_VIS_in_background10.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.4_VIS_in_background10.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.6_VIS_in_background10.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_0.8_VIS_in_background10.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_109_1_VIS_in_background10.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.05_VIS_in_background11.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.15_VIS_in_background11.fits
# Magnitud: 0.15, Dice: 0.3213 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.1_VIS_in_background11.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.25_VIS_in_background11.fits
# Magnitud: 0.25, Dice: 0.1926 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.2_VIS_in_background11.fits
# Magnitud: 0.2, Dice: 0.3048 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.4_VIS_in_background11.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.6_VIS_in_background11.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_0.8_VIS_in_background11.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_10_1_VIS_in_background11.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.15_VIS_in_background12.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.1_VIS_in_background12.fits
# Magnitud: 0.1, Dice: 0.066 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.25_VIS_in_background12.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.2_VIS_in_background12.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.4_VIS_in_background12.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.6_VIS_in_background12.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_0.8_VIS_in_background12.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_110_1_VIS_in_background12.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.05_VIS_in_background13.fits
# Magnitud: 0.05, Dice: 0.8768 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.15_VIS_in_background13.fits
# Magnitud: 0.15, Dice: 0.7531 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.1_VIS_in_background13.fits
# Magnitud: 0.1, Dice: 0.8197 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.25_VIS_in_background13.fits
# Magnitud: 0.25, Dice: 0.6965 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.2_VIS_in_background13.fits
# Magnitud: 0.2, Dice: 0.6687 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.4_VIS_in_background13.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.6_VIS_in_background13.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_0.8_VIS_in_background13.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_111_1_VIS_in_background13.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.05_VIS_in_background14.fits
# Magnitud: 0.05, Dice: 0.6501 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.15_VIS_in_background14.fits
# Magnitud: 0.15, Dice: 0.6389 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.1_VIS_in_background14.fits
# Magnitud: 0.1, Dice: 0.6746 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.25_VIS_in_background14.fits
# Magnitud: 0.25, Dice: 0.1762 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.2_VIS_in_background14.fits
# Magnitud: 0.2, Dice: 0.4628 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.4_VIS_in_background14.fits
# Magnitud: 0.4, Dice: 0.2431 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.6_VIS_in_background14.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_0.8_VIS_in_background14.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_112_1_VIS_in_background14.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.05_VIS_in_background15.fits
# Magnitud: 0.05, Dice: 0.5499 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.15_VIS_in_background15.fits
# Magnitud: 0.15, Dice: 0.6794 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.1_VIS_in_background15.fits
# Magnitud: 0.1, Dice: 0.8061 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.25_VIS_in_background15.fits
# Magnitud: 0.25, Dice: 0.4392 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.2_VIS_in_background15.fits
# Magnitud: 0.2, Dice: 0.5168 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.4_VIS_in_background15.fits
# Magnitud: 0.4, Dice: 0.6604 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.6_VIS_in_background15.fits
# Magnitud: 0.6, Dice: 0.4449 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_0.8_VIS_in_background15.fits
# Magnitud: 0.8, Dice: 0.2229 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_113_1_VIS_in_background15.fits
# Magnitud: 1, Dice: 0.129 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.05_VIS_in_background16.fits
# Magnitud: 0.05, Dice: 0.1608 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.15_VIS_in_background16.fits
# Magnitud: 0.15, Dice: 0.8335 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.1_VIS_in_background16.fits
# Magnitud: 0.1, Dice: 0.5107 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.25_VIS_in_background16.fits
# Magnitud: 0.25, Dice: 0.8872 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.2_VIS_in_background16.fits
# Magnitud: 0.2, Dice: 0.9044 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.4_VIS_in_background16.fits
# Magnitud: 0.4, Dice: 0.7189 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.6_VIS_in_background16.fits
# Magnitud: 0.6, Dice: 0.6339 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_0.8_VIS_in_background16.fits
# Magnitud: 0.8, Dice: 0.6216 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_114_1_VIS_in_background16.fits
# Magnitud: 1, Dice: 0.3913 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.05_VIS_in_background17.fits
# Magnitud: 0.05, Dice: 0.6545 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.15_VIS_in_background17.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.1_VIS_in_background17.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.25_VIS_in_background17.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.2_VIS_in_background17.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.4_VIS_in_background17.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.6_VIS_in_background17.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_0.8_VIS_in_background17.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_115_1_VIS_in_background17.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.05_VIS_in_background18.fits
# Magnitud: 0.05, Dice: 0.394 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.15_VIS_in_background18.fits
# Magnitud: 0.15, Dice: 0.8868 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.1_VIS_in_background18.fits
# Magnitud: 0.1, Dice: 0.8679 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.25_VIS_in_background18.fits
# Magnitud: 0.25, Dice: 0.8641 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.2_VIS_in_background18.fits
# Magnitud: 0.2, Dice: 0.8368 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.4_VIS_in_background18.fits
# Magnitud: 0.4, Dice: 0.8895 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.6_VIS_in_background18.fits
# Magnitud: 0.6, Dice: 0.7984 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_0.8_VIS_in_background18.fits
# Magnitud: 0.8, Dice: 0.6328 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_116_1_VIS_in_background18.fits
# Magnitud: 1, Dice: 0.6667 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.05_VIS_in_background19.fits
# Magnitud: 0.05, Dice: 0.1318 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.15_VIS_in_background19.fits
# Magnitud: 0.15, Dice: 0.2114 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.1_VIS_in_background19.fits
# Magnitud: 0.1, Dice: 0.3842 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.25_VIS_in_background19.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.2_VIS_in_background19.fits
# Magnitud: 0.2, Dice: 0.0152 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.4_VIS_in_background19.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.6_VIS_in_background19.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_0.8_VIS_in_background19.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_117_1_VIS_in_background19.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.05_VIS_in_background20.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.15_VIS_in_background20.fits
# Magnitud: 0.15, Dice: 0.4207 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.1_VIS_in_background20.fits
# Magnitud: 0.1, Dice: 0.4731 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.25_VIS_in_background20.fits
# Magnitud: 0.25, Dice: 0.6397 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.2_VIS_in_background20.fits
# Magnitud: 0.2, Dice: 0.6262 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.4_VIS_in_background20.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.6_VIS_in_background20.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_0.8_VIS_in_background20.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_118_1_VIS_in_background20.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.15_VIS_in_background21.fits
# Magnitud: 0.15, Dice: 0.3106 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.1_VIS_in_background21.fits
# Magnitud: 0.1, Dice: 0.0588 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.25_VIS_in_background21.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.2_VIS_in_background21.fits
# Magnitud: 0.2, Dice: 0.0204 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.4_VIS_in_background21.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.6_VIS_in_background21.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_0.8_VIS_in_background21.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_119_1_VIS_in_background21.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.05_VIS_in_background22.fits
# Magnitud: 0.05, Dice: 0.181 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.15_VIS_in_background22.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.1_VIS_in_background22.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.25_VIS_in_background22.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.2_VIS_in_background22.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.4_VIS_in_background22.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.6_VIS_in_background22.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_0.8_VIS_in_background22.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_11_1_VIS_in_background22.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.05_VIS_in_background23.fits
# Magnitud: 0.05, Dice: 0.4587 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.15_VIS_in_background23.fits
# Magnitud: 0.15, Dice: 0.2452 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.1_VIS_in_background23.fits
# Magnitud: 0.1, Dice: 0.5549 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.25_VIS_in_background23.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.2_VIS_in_background23.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.4_VIS_in_background23.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.6_VIS_in_background23.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_0.8_VIS_in_background23.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_120_1_VIS_in_background23.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.05_VIS_in_background24.fits
# Magnitud: 0.05, Dice: 0.3924 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.15_VIS_in_background24.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.1_VIS_in_background24.fits
# Magnitud: 0.1, Dice: 0.3295 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.25_VIS_in_background24.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.2_VIS_in_background24.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.4_VIS_in_background24.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.6_VIS_in_background24.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_0.8_VIS_in_background24.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_121_1_VIS_in_background24.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.15_VIS_in_background25.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.1_VIS_in_background25.fits
# Magnitud: 0.1, Dice: 0.1731 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.25_VIS_in_background25.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.2_VIS_in_background25.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.4_VIS_in_background25.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.6_VIS_in_background25.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_0.8_VIS_in_background25.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_122_1_VIS_in_background25.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.05_VIS_in_background26.fits
# Magnitud: 0.05, Dice: 0.6569 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.15_VIS_in_background26.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.1_VIS_in_background26.fits
# Magnitud: 0.1, Dice: 0.1875 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.25_VIS_in_background26.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.2_VIS_in_background26.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.4_VIS_in_background26.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.6_VIS_in_background26.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_0.8_VIS_in_background26.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_123_1_VIS_in_background26.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.05_VIS_in_background27.fits
# Magnitud: 0.05, Dice: 0.2332 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.15_VIS_in_background27.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.1_VIS_in_background27.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.25_VIS_in_background27.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.2_VIS_in_background27.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_124_0.4_VIS_in_background27.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.05_VIS_in_background28.fits
# Magnitud: 0.05, Dice: 0.5479 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.15_VIS_in_background28.fits
# Magnitud: 0.15, Dice: 0.1162 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.1_VIS_in_background28.fits
# Magnitud: 0.1, Dice: 0.4488 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.25_VIS_in_background28.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.2_VIS_in_background28.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.4_VIS_in_background28.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.6_VIS_in_background28.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_0.8_VIS_in_background28.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_125_1_VIS_in_background28.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.15_VIS_in_background29.fits
# Magnitud: 0.15, Dice: 0.8378 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.1_VIS_in_background29.fits
# Magnitud: 0.1, Dice: 0.8021 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.25_VIS_in_background29.fits
# Magnitud: 0.25, Dice: 0.7789 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.2_VIS_in_background29.fits
# Magnitud: 0.2, Dice: 0.8689 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.4_VIS_in_background29.fits
# Magnitud: 0.4, Dice: 0.5906 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.6_VIS_in_background29.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_0.8_VIS_in_background29.fits
# Magnitud: 0.8, Dice: 0.1452 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_126_1_VIS_in_background29.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.15_VIS_in_background30.fits
# Magnitud: 0.15, Dice: 0.686 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.1_VIS_in_background30.fits
# Magnitud: 0.1, Dice: 0.2622 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.25_VIS_in_background30.fits
# Magnitud: 0.25, Dice: 0.6073 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.2_VIS_in_background30.fits
# Magnitud: 0.2, Dice: 0.5906 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.4_VIS_in_background30.fits
# Magnitud: 0.4, Dice: 0.6356 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.6_VIS_in_background30.fits
# Magnitud: 0.6, Dice: 0.6499 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_0.8_VIS_in_background30.fits
# Magnitud: 0.8, Dice: 0.3451 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_127_1_VIS_in_background30.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.05_VIS_in_background31.fits
# Magnitud: 0.05, Dice: 0.015 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.15_VIS_in_background31.fits
# Magnitud: 0.15, Dice: 0.0448 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.1_VIS_in_background31.fits
# Magnitud: 0.1, Dice: 0.5048 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.25_VIS_in_background31.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.2_VIS_in_background31.fits
# Magnitud: 0.2, Dice: 0.0063 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.4_VIS_in_background31.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.6_VIS_in_background31.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_0.8_VIS_in_background31.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_128_1_VIS_in_background31.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.15_VIS_in_background32.fits
# Magnitud: 0.15, Dice: 0.7796 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.1_VIS_in_background32.fits
# Magnitud: 0.1, Dice: 0.4383 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.25_VIS_in_background32.fits
# Magnitud: 0.25, Dice: 0.8647 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.2_VIS_in_background32.fits
# Magnitud: 0.2, Dice: 0.7966 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.4_VIS_in_background32.fits
# Magnitud: 0.4, Dice: 0.6722 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.6_VIS_in_background32.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_0.8_VIS_in_background32.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_129_1_VIS_in_background32.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.15_VIS_in_background33.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.1_VIS_in_background33.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.25_VIS_in_background33.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.2_VIS_in_background33.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.4_VIS_in_background33.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.6_VIS_in_background33.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_0.8_VIS_in_background33.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_12_1_VIS_in_background33.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.15_VIS_in_background34.fits
# Magnitud: 0.15, Dice: 0.774 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.1_VIS_in_background34.fits
# Magnitud: 0.1, Dice: 0.6595 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.25_VIS_in_background34.fits
# Magnitud: 0.25, Dice: 0.8464 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.2_VIS_in_background34.fits
# Magnitud: 0.2, Dice: 0.8416 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.4_VIS_in_background34.fits
# Magnitud: 0.4, Dice: 0.7975 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.6_VIS_in_background34.fits
# Magnitud: 0.6, Dice: 0.6623 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_0.8_VIS_in_background34.fits
# Magnitud: 0.8, Dice: 0.5274 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_130_1_VIS_in_background34.fits
# Magnitud: 1, Dice: 0.3667 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.05_VIS_in_background35.fits
# Magnitud: 0.05, Dice: 0.4838 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.15_VIS_in_background35.fits
# Magnitud: 0.15, Dice: 0.276 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.1_VIS_in_background35.fits
# Magnitud: 0.1, Dice: 0.4441 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.25_VIS_in_background35.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.2_VIS_in_background35.fits
# Magnitud: 0.2, Dice: 0.2834 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.4_VIS_in_background35.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.6_VIS_in_background35.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_0.8_VIS_in_background35.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_131_1_VIS_in_background35.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.05_VIS_in_background36.fits
# Magnitud: 0.05, Dice: 0.8271 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.15_VIS_in_background36.fits
# Magnitud: 0.15, Dice: 0.8158 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.1_VIS_in_background36.fits
# Magnitud: 0.1, Dice: 0.816 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.25_VIS_in_background36.fits
# Magnitud: 0.25, Dice: 0.7889 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.2_VIS_in_background36.fits
# Magnitud: 0.2, Dice: 0.7351 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.4_VIS_in_background36.fits
# Magnitud: 0.4, Dice: 0.6239 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.6_VIS_in_background36.fits
# Magnitud: 0.6, Dice: 0.6322 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_0.8_VIS_in_background36.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_132_1_VIS_in_background36.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.05_VIS_in_background37.fits
# Magnitud: 0.05, Dice: 0.658 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.15_VIS_in_background37.fits
# Magnitud: 0.15, Dice: 0.7193 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.1_VIS_in_background37.fits
# Magnitud: 0.1, Dice: 0.6813 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.25_VIS_in_background37.fits
# Magnitud: 0.25, Dice: 0.7283 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.2_VIS_in_background37.fits
# Magnitud: 0.2, Dice: 0.7278 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.4_VIS_in_background37.fits
# Magnitud: 0.4, Dice: 0.6839 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.6_VIS_in_background37.fits
# Magnitud: 0.6, Dice: 0.4302 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_0.8_VIS_in_background37.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_133_1_VIS_in_background37.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.05_VIS_in_background38.fits
# Magnitud: 0.05, Dice: 0.5719 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.15_VIS_in_background38.fits
# Magnitud: 0.15, Dice: 0.1206 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.1_VIS_in_background38.fits
# Magnitud: 0.1, Dice: 0.2792 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.25_VIS_in_background38.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.2_VIS_in_background38.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.4_VIS_in_background38.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.6_VIS_in_background38.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_0.8_VIS_in_background38.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_134_1_VIS_in_background38.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.05_VIS_in_background39.fits
# Magnitud: 0.05, Dice: 0.5552 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.15_VIS_in_background39.fits
# Magnitud: 0.15, Dice: 0.7151 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.1_VIS_in_background39.fits
# Magnitud: 0.1, Dice: 0.7381 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.25_VIS_in_background39.fits
# Magnitud: 0.25, Dice: 0.3753 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.2_VIS_in_background39.fits
# Magnitud: 0.2, Dice: 0.7106 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.4_VIS_in_background39.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.6_VIS_in_background39.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_0.8_VIS_in_background39.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_135_1_VIS_in_background39.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.05_VIS_in_background40.fits
# Magnitud: 0.05, Dice: 0.0017 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.15_VIS_in_background40.fits
# Magnitud: 0.15, Dice: 0.1136 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.1_VIS_in_background40.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.25_VIS_in_background40.fits
# Magnitud: 0.25, Dice: 0.1412 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.2_VIS_in_background40.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.4_VIS_in_background40.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.6_VIS_in_background40.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_0.8_VIS_in_background40.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_136_1_VIS_in_background40.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.05_VIS_in_background41.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.15_VIS_in_background41.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.1_VIS_in_background41.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.25_VIS_in_background41.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.2_VIS_in_background41.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.4_VIS_in_background41.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.6_VIS_in_background41.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_0.8_VIS_in_background41.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_137_1_VIS_in_background41.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.05_VIS_in_background42.fits
# Magnitud: 0.05, Dice: 0.4813 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.15_VIS_in_background42.fits
# Magnitud: 0.15, Dice: 0.4368 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.1_VIS_in_background42.fits
# Magnitud: 0.1, Dice: 0.7424 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.25_VIS_in_background42.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.2_VIS_in_background42.fits
# Magnitud: 0.2, Dice: 0.2543 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.4_VIS_in_background42.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.6_VIS_in_background42.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_0.8_VIS_in_background42.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_138_1_VIS_in_background42.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.05_VIS_in_background43.fits
# Magnitud: 0.05, Dice: 0.727 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.15_VIS_in_background43.fits
# Magnitud: 0.15, Dice: 0.6261 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.1_VIS_in_background43.fits
# Magnitud: 0.1, Dice: 0.7278 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.25_VIS_in_background43.fits
# Magnitud: 0.25, Dice: 0.1897 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.2_VIS_in_background43.fits
# Magnitud: 0.2, Dice: 0.4372 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.4_VIS_in_background43.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.6_VIS_in_background43.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_0.8_VIS_in_background43.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_139_1_VIS_in_background43.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.05_VIS_in_background44.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.15_VIS_in_background44.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.1_VIS_in_background44.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.25_VIS_in_background44.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.2_VIS_in_background44.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.4_VIS_in_background44.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.6_VIS_in_background44.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_0.8_VIS_in_background44.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_13_1_VIS_in_background44.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.15_VIS_in_background45.fits
# Magnitud: 0.15, Dice: 0.3723 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.1_VIS_in_background45.fits
# Magnitud: 0.1, Dice: 0.451 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.25_VIS_in_background45.fits
# Magnitud: 0.25, Dice: 0.2103 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.2_VIS_in_background45.fits
# Magnitud: 0.2, Dice: 0.3874 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.4_VIS_in_background45.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.6_VIS_in_background45.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_0.8_VIS_in_background45.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_140_1_VIS_in_background45.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.15_VIS_in_background46.fits
# Magnitud: 0.15, Dice: 0.6445 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.1_VIS_in_background46.fits
# Magnitud: 0.1, Dice: 0.3771 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.25_VIS_in_background46.fits
# Magnitud: 0.25, Dice: 0.6677 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.2_VIS_in_background46.fits
# Magnitud: 0.2, Dice: 0.6493 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.4_VIS_in_background46.fits
# Magnitud: 0.4, Dice: 0.6135 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.6_VIS_in_background46.fits
# Magnitud: 0.6, Dice: 0.4472 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_0.8_VIS_in_background46.fits
# Magnitud: 0.8, Dice: 0.4122 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_141_1_VIS_in_background46.fits
# Magnitud: 1, Dice: 0.3587 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.05_VIS_in_background47.fits
# Magnitud: 0.05, Dice: 0.2989 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.15_VIS_in_background47.fits
# Magnitud: 0.15, Dice: 0.8574 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.1_VIS_in_background47.fits
# Magnitud: 0.1, Dice: 0.7526 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.25_VIS_in_background47.fits
# Magnitud: 0.25, Dice: 0.8816 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.2_VIS_in_background47.fits
# Magnitud: 0.2, Dice: 0.8891 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.4_VIS_in_background47.fits
# Magnitud: 0.4, Dice: 0.7554 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.6_VIS_in_background47.fits
# Magnitud: 0.6, Dice: 0.7081 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_0.8_VIS_in_background47.fits
# Magnitud: 0.8, Dice: 0.5714 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_142_1_VIS_in_background47.fits
# Magnitud: 1, Dice: 0.069 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.05_VIS_in_background48.fits
# Magnitud: 0.05, Dice: 0.3992 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.15_VIS_in_background48.fits
# Magnitud: 0.15, Dice: 0.5058 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.1_VIS_in_background48.fits
# Magnitud: 0.1, Dice: 0.3893 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.25_VIS_in_background48.fits
# Magnitud: 0.25, Dice: 0.2694 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.2_VIS_in_background48.fits
# Magnitud: 0.2, Dice: 0.4384 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.4_VIS_in_background48.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_143_0.6_VIS_in_background48.fits
# Magnitud: 0.6, Dice: 0.0 :
# ...
# Magnitud: 0.05, Dice: 0.7586 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.15_VIS_in_background184.fits
# Magnitud: 0.15, Dice: 0.733 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.1_VIS_in_background184.fits
# Magnitud: 0.1, Dice: 0.8428 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.25_VIS_in_background184.fits
# Magnitud: 0.25, Dice: 0.4039 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.2_VIS_in_background184.fits
# Magnitud: 0.2, Dice: 0.627 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.4_VIS_in_background184.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.6_VIS_in_background184.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_0.8_VIS_in_background184.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_266_1_VIS_in_background184.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.15_VIS_in_background185.fits
# Magnitud: 0.15, Dice: 0.632 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.1_VIS_in_background185.fits
# Magnitud: 0.1, Dice: 0.6766 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.25_VIS_in_background185.fits
# Magnitud: 0.25, Dice: 0.681 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.2_VIS_in_background185.fits
# Magnitud: 0.2, Dice: 0.6831 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.4_VIS_in_background185.fits
# Magnitud: 0.4, Dice: 0.7004 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.6_VIS_in_background185.fits
# Magnitud: 0.6, Dice: 0.39 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_0.8_VIS_in_background185.fits
# Magnitud: 0.8, Dice: 0.315 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_267_1_VIS_in_background185.fits
# Magnitud: 1, Dice: 0.2202 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.15_VIS_in_background186.fits
# Magnitud: 0.15, Dice: 0.8312 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.1_VIS_in_background186.fits
# Magnitud: 0.1, Dice: 0.5654 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.25_VIS_in_background186.fits
# Magnitud: 0.25, Dice: 0.6822 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.2_VIS_in_background186.fits
# Magnitud: 0.2, Dice: 0.7495 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.4_VIS_in_background186.fits
# Magnitud: 0.4, Dice: 0.622 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.6_VIS_in_background186.fits
# Magnitud: 0.6, Dice: 0.6826 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_0.8_VIS_in_background186.fits
# Magnitud: 0.8, Dice: 0.25 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_268_1_VIS_in_background186.fits
# Magnitud: 1, Dice: 0.044 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.05_VIS_in_background187.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.15_VIS_in_background187.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.1_VIS_in_background187.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.25_VIS_in_background187.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.2_VIS_in_background187.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.4_VIS_in_background187.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.6_VIS_in_background187.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_0.8_VIS_in_background187.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_269_1_VIS_in_background187.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.05_VIS_in_background188.fits
# Magnitud: 0.05, Dice: 0.7252 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.15_VIS_in_background188.fits
# Magnitud: 0.15, Dice: 0.7942 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.1_VIS_in_background188.fits
# Magnitud: 0.1, Dice: 0.7968 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.25_VIS_in_background188.fits
# Magnitud: 0.25, Dice: 0.6742 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.2_VIS_in_background188.fits
# Magnitud: 0.2, Dice: 0.7702 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.4_VIS_in_background188.fits
# Magnitud: 0.4, Dice: 0.5867 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.6_VIS_in_background188.fits
# Magnitud: 0.6, Dice: 0.3736 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_0.8_VIS_in_background188.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_26_1_VIS_in_background188.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.05_VIS_in_background189.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.15_VIS_in_background189.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.1_VIS_in_background189.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.25_VIS_in_background189.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.2_VIS_in_background189.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.4_VIS_in_background189.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.6_VIS_in_background189.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_0.8_VIS_in_background189.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_270_1_VIS_in_background189.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.05_VIS_in_background190.fits
# Magnitud: 0.05, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.15_VIS_in_background190.fits
# Magnitud: 0.15, Dice: 0.4706 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.1_VIS_in_background190.fits
# Magnitud: 0.1, Dice: 0.4858 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.25_VIS_in_background190.fits
# Magnitud: 0.25, Dice: 0.5737 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.2_VIS_in_background190.fits
# Magnitud: 0.2, Dice: 0.6197 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.4_VIS_in_background190.fits
# Magnitud: 0.4, Dice: 0.0361 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.6_VIS_in_background190.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_0.8_VIS_in_background190.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_271_1_VIS_in_background190.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.05_VIS_in_background191.fits
# Magnitud: 0.05, Dice: 0.5553 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.15_VIS_in_background191.fits
# Magnitud: 0.15, Dice: 0.7947 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.1_VIS_in_background191.fits
# Magnitud: 0.1, Dice: 0.7685 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.25_VIS_in_background191.fits
# Magnitud: 0.25, Dice: 0.4049 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.2_VIS_in_background191.fits
# Magnitud: 0.2, Dice: 0.806 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.4_VIS_in_background191.fits
# Magnitud: 0.4, Dice: 0.305 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.6_VIS_in_background191.fits
# Magnitud: 0.6, Dice: 0.1429 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_0.8_VIS_in_background191.fits
# Magnitud: 0.8, Dice: 0.1467 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_272_1_VIS_in_background191.fits
# Magnitud: 1, Dice: 0.2267 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.05_VIS_in_background192.fits
# Magnitud: 0.05, Dice: 0.329 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.15_VIS_in_background192.fits
# Magnitud: 0.15, Dice: 0.4586 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.1_VIS_in_background192.fits
# Magnitud: 0.1, Dice: 0.4731 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.25_VIS_in_background192.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.2_VIS_in_background192.fits
# Magnitud: 0.2, Dice: 0.0093 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.4_VIS_in_background192.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.6_VIS_in_background192.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_0.8_VIS_in_background192.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_273_1_VIS_in_background192.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.05_VIS_in_background193.fits
# Magnitud: 0.05, Dice: 0.5058 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.15_VIS_in_background193.fits
# Magnitud: 0.15, Dice: 0.3262 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.1_VIS_in_background193.fits
# Magnitud: 0.1, Dice: 0.2873 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.25_VIS_in_background193.fits
# Magnitud: 0.25, Dice: 0.0967 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.2_VIS_in_background193.fits
# Magnitud: 0.2, Dice: 0.1089 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.4_VIS_in_background193.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.6_VIS_in_background193.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_0.8_VIS_in_background193.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_274_1_VIS_in_background193.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.05_VIS_in_background194.fits
# Magnitud: 0.05, Dice: 0.5682 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.15_VIS_in_background194.fits
# Magnitud: 0.15, Dice: 0.6122 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.1_VIS_in_background194.fits
# Magnitud: 0.1, Dice: 0.5778 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.25_VIS_in_background194.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.2_VIS_in_background194.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.4_VIS_in_background194.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.6_VIS_in_background194.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_0.8_VIS_in_background194.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_275_1_VIS_in_background194.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.05_VIS_in_background195.fits
# Magnitud: 0.05, Dice: 0.5924 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.15_VIS_in_background195.fits
# Magnitud: 0.15, Dice: 0.8714 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.1_VIS_in_background195.fits
# Magnitud: 0.1, Dice: 0.7867 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.25_VIS_in_background195.fits
# Magnitud: 0.25, Dice: 0.7469 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.2_VIS_in_background195.fits
# Magnitud: 0.2, Dice: 0.7657 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.4_VIS_in_background195.fits
# Magnitud: 0.4, Dice: 0.6712 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.6_VIS_in_background195.fits
# Magnitud: 0.6, Dice: 0.1206 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_0.8_VIS_in_background195.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_276_1_VIS_in_background195.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.05_VIS_in_background196.fits
# Magnitud: 0.05, Dice: 0.597 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.15_VIS_in_background196.fits
# Magnitud: 0.15, Dice: 0.1913 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.1_VIS_in_background196.fits
# Magnitud: 0.1, Dice: 0.2736 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.25_VIS_in_background196.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.2_VIS_in_background196.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.4_VIS_in_background196.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.6_VIS_in_background196.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_0.8_VIS_in_background196.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_277_1_VIS_in_background196.fits
# Magnitud: 1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.15_VIS_in_background197.fits
# Magnitud: 0.15, Dice: 0.406 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.25_VIS_in_background197.fits
# Magnitud: 0.25, Dice: 0.4861 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.2_VIS_in_background197.fits
# Magnitud: 0.2, Dice: 0.5754 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.4_VIS_in_background197.fits
# Magnitud: 0.4, Dice: 0.7397 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.6_VIS_in_background197.fits
# Magnitud: 0.6, Dice: 0.6494 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_0.8_VIS_in_background197.fits
# Magnitud: 0.8, Dice: 0.584 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_278_1_VIS_in_background197.fits
# Magnitud: 1, Dice: 0.5325 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.05_VIS_in_background198.fits
# Magnitud: 0.05, Dice: 0.5369 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.15_VIS_in_background198.fits
# Magnitud: 0.15, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.1_VIS_in_background198.fits
# Magnitud: 0.1, Dice: 0.0029 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.25_VIS_in_background198.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.2_VIS_in_background198.fits
# Magnitud: 0.2, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.4_VIS_in_background198.fits
# Magnitud: 0.4, Dice: 0.6264 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.6_VIS_in_background198.fits
# Magnitud: 0.6, Dice: 0.664 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_0.8_VIS_in_background198.fits
# Magnitud: 0.8, Dice: 0.565 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_279_1_VIS_in_background198.fits
# Magnitud: 1, Dice: 0.4928 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.05_VIS_in_background199.fits
# Magnitud: 0.05, Dice: 0.0043 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.15_VIS_in_background199.fits
# Magnitud: 0.15, Dice: 0.0223 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.1_VIS_in_background199.fits
# Magnitud: 0.1, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.25_VIS_in_background199.fits
# Magnitud: 0.25, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.2_VIS_in_background199.fits
# Magnitud: 0.2, Dice: 0.0414 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.4_VIS_in_background199.fits
# Magnitud: 0.4, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.6_VIS_in_background199.fits
# Magnitud: 0.6, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_0.8_VIS_in_background199.fits
# Magnitud: 0.8, Dice: 0.0 :
# Ruta: galaxies_test_VIS/galaxy_and_stream_convolved_27_1_VIS_in_background199.fits
# Magnitud: 1, Dice: 0.0 :

# %%
dice_test_medio_total=dice_medio_test/pasos_test
print("Dice_medio_total="+str(dice_test_medio_total))
# Out:
# Dice_medio_total=0.27534476010084863

# %%
iou_test_medio_total=iou_medio_test/pasos_test
print("IOU_medio_total="+str(iou_test_medio_total))
# Out:
# IOU_medio_total=nan

# %%
# Filtrar NaNs y calcular la media para resultados_dice
dices_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_dice.values()]
print(dices_medios_por_magnitud)
# Filtrar NaNs y calcular la media para resultados_iou
ious_medios_por_magnitud = [np.mean([x for x in lista if not np.isnan(x)]) for lista in resultados_iou.values()]
print(ious_medios_por_magnitud)
# Out:
# [0.36688346885133283, 0.42882999415901785, 0.4158011968818027, 0.37528374306624757, 0.336401394684799, 0.2582199269160628, 0.14880063522363726, 0.09489432606265773, 0.06966170662985974]
# [0.7565406061864147, 0.8115103784515414, 0.8151443723589182, 0.835712680593133, 0.8344130971729755, 0.8103577556586502, 0.8049204069287029, 0.722012275711019, 0.6616838654503227]

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in dices_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(dices_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('Dice', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_870649/1722266948.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=dices_medios_por_magnitud, palette=bar_colors)

# %%
# Crear una paleta de colores en función de los valores alcanzados, normalizada entre 0 y 1
norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="magma", norm=norm)
sm.set_array([])

# Ajustar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras
bar_colors = [sm.to_rgba(valor) for valor in ious_medios_por_magnitud]
ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)

# Ajustar los límites del eje y entre 0 y 1
ax.set_ylim(0, 1)

# Añadir etiquetas con los valores sobre las barras
for i, valor in enumerate(ious_medios_por_magnitud):
    ax.text(i, valor + 0.01, f'{valor:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Añadir un título y ajustar etiquetas
plt.title('VIS Filter', fontsize=20, fontweight='bold')
plt.xlabel('Redshift', fontsize=16)
plt.ylabel('IOU', fontsize=16)

# Ajustar el tamaño de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Añadir líneas de cuadrícula
ax.grid(True, linestyle='--', linewidth=0.5)

# Añadir la barra de color (colorbar)
cbar = plt.colorbar(sm, ax=ax)

# Mejorar el diseño general
sns.despine()
#plt.savefig('images_paper/vis_filter_dice.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_870649/3865062909.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(resultados_dice.keys()), y=ious_medios_por_magnitud, palette=bar_colors)
